# %% [markdown]
# # Building DB of not_100 songs
# 1. Discogs 3,000 songs
# 3. Kaggle DB 500 songs
# 4. Spotify 500 songs - with my selected artists/playlists:

# %%
import requests # to download html code
from bs4 import BeautifulSoup # to navigate through the html code
import pandas as pd
import numpy as np
import re  #regexp

# %%
url = "https://www.discogs.com/search/?limit=250&sort=have%2Cdesc&type=release&page=1"

# %%
# 3. download html with a get request. Use the function request.get() and store the output in response
response = requests.get(url)
# 200 status code means OK! response.status_code
print(response.status_code)
# Out:
# 200

# %%
# 4.1. parse html (create the 'soup')
soup = BeautifulSoup(response.text, 'html.parser')
# 4.2. check that the html code looks like it should
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="is_not_mobile needs_reduced_ui" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="en" http-equiv="content-language"/>
#   <meta content="no-cache" http-equiv="pragma">
#    <meta content="-1" http-equiv="expires">
#     <!-- OT will rewrite convert these to javascript and update our consent module accordingly -->
#     <script class="optanon-category-C0002" type="text/plain">
#      window.consent.resolveGroup(window.consent.PERFORMANCE_GROUP)
#     </script>
#     <script class="optanon-category-C0003" type="text/plain">
#      window.consent.resolveGroup(window.consent.FUNCTIONALITY_GROUP)
#     </script>
#     <script class="optanon-category-C0004" type="text/plain">
#      window.consent.resolveGroup(window.consent.TARGETING_GROUP)
#     </script>
#     <meta content="initial-scale=1.0,width=device-width" id="viewport" name="viewport">
#      <script>
#       if (window.innerWidth <= 600) document.getElementById('viewport').setAttribute('content', 'initial-scale=1.0, minimum-scale 1.0, width="device-width"');
#      </script>
#      <script type="text/javascript">
#       window.__start = new Date().getTime();
#      </script>
#      <script type="text/javascript">
#       // dataLayer additions consumed by Google Tag Manager for later submission
#             // to Google Analytics - this object is added to _every_ page.
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push({
#                 'event': 'dataLayer-initialized',
#                 'userId': undefined,
#                 'loggedIn': false,
#                 'siteVersion': undefined,
#                 'pageCategory': "search.query"
#             });
#      </script>
#      <meta content="Discover music on Discogs, the largest online music database. Buy and sell music with collectors in the Marketplace." name="description"/>
#      <meta content="vinyl records, used cds, discography, database, new, used, cds, lps, vinyl record, albums, rare cds, rare records, music albums, music cds, cd single, music cd, cd singles, rare lps, hard to find music, out of print music, cheap cds, cheap music, rare vinyl records, used music" name="keywords"/>
#      <meta content="117175028305858" property="fb:app_id"/>
#      <meta content="noindex, nofollow" name="robots">
#       <script src="https://lngtd.com/discogs_b.js" type="text/javascript">
#       </script>
#       <title>
#        Find Music on Discogs | Discogs
#       </title>
#       <link id="rel_next" rel="next" url="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=2"/>
#       <link href="https://www.discogs.com/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1" hreflang="en" rel="alternate">
#        <link href="https://www.discogs.com/de/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1" hreflang="de" rel="alternate"/>
#        <link href="https://www.discogs.com/es/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1" hreflang="es" rel="alternate"/>
#        <link href="https://www.discogs.com/fr/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1" hreflang="fr" rel="alternate"/>
#        <link href="https://www.discogs.com/it/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1" hreflang="it" rel="alternate"/>
#        <link href="https://www.discogs.com/ja/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1" hreflang="ja" rel="alternate"/>
#        <link href="https://www.discogs.com/ko/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1" hreflang="ko" rel="alternate"/>
#        <link href="https://www.discogs.com/pt_BR/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1" hreflang="pt-BR" rel="alternate"/>
#        <link href="https://www.discogs.com/ru/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1" hreflang="ru" rel="alternate"/>
#        <link href="https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/dst/stylesheets/discogs.css" rel="stylesheet" type="text/css"/>
#        <link href="https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/images/favicon.ico" rel="icon"/>
#        <link href="https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/images/favicon-16x16.png" rel="icon" sizes="16x16"/>
#        <link href="https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/images/favicon-32x32.png" rel="icon" sizes="32x32"/>
#        <link href="https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/images/favicon-96x96.png" rel="icon" sizes="96x96"/>
#        <link href="https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/images/apple-touch-icon-precomposed.png" rel="apple-touch-icon"/>
#        <link color="black" href="https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/images/discogs-record-icon.svg" rel="mask-icon"/>
#        <script id="dsdata">
#         function dsdata (){
#                 return {"activationHelpUrl": "/help/doc/activation", "apiServer": "https://api.discogs.com", "appEnv": "production", "assetBasePath": "53735943f116d10c83937e2c850ad367a600ecc9/dst/", "assetsHost": "https://s.discogs.com/", "autocompleteUrl": "/search/ac", "cookieDomain": "www.discogs.com", "countryAbbr": "gb", "countryName": "United Kingdom", "dataLayer": [], "defaultLocale": "en", "enableGaDebugging": false, "enableGaDebuggingVerbose": false, "enableGoogleAnalytics": true, "endpoint": "search.query", "ga_pageview_page": "/home", "ga_pageview_title": "home", "isDiscogsApp": false, "isMobile": false, "locale": "en", "loginUrl": "https://www.discogs.com/login", "mp_web": {"cart_anon": true}, "recaptchaKey": "6LdGMgITAAAAAPG6lAC5r1yck_LpHUbQs4IbnNtV", "requireCookieConsent": true, "sentryKey": "https://387a0c015e78429ca256c602993e2b92@sentry.io/51758", "sha": "53735943f116d10c83937e2c850ad367a600ecc9", "useSentry": true, "userIsAdmin": false, "userIsRegistered": false, "searchQuery": "", "pagination_limit": 250, "searchTotal": 15052124, "adsObject": {"genres": [], "styles": [], "query": {"type": "release"}}};
#             }
#        </script>
#        <script>
#         window.ds = typeof window.ds == "function" ? window.ds : function(){
#                 (ds.q = ds.q || []).push(arguments);
#                 return ds;
#             };
#        </script>
#       </link>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body class="">
#   <div id="main_wrapper">
#    <div id="site_headers_super_wrap">
#     <div id="site_header_wrap">
#      <div aria-label="Discogs Header" id="site_header" role="banner">
#       <a href="/" id="header_logo" title="Go to Discogs.com homepage">
#        <img alt="" src="https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/images/discogs-white.png?5"/>
#       </a>
#       <form action="/search/" aria-label="Search Discogs" id="site_search" role="search">
#        <input aria-label="Search artists, albums and more..." autocapitalize="off" autocorrect="off" class="autocomplete ac_type_a_m_r_13 ac_submit init" id="search_q" name="q" placeholder="Search artists, albums and more..." type="text" value=""/>
#        <button aria-label="Search" class="submit button" id="do_site_search" name="" type="submit" value="">
#         <i class="icon icon-search">
#         </i>
#        </button>
#        <input class="advanced_search advanced_search_type" name="type" type="hidden" value="all"/>
#       </form>
#       <ul aria-label="Main Navigation" id="site_navigation" role="navigation">
#        <li class="site_nav_group" data-id="explore" id="section_nav_explore">
#         <a class="nav_group_control" href="/search/">
#          Explore
#          <i class="icon icon-caret-down">
#          </i>
#         </a>
#         <div class="site_nav_submenu site_nav_tray" id="site_nav_tray_explore">
#          <table>
#           <tr>
#            <td>
#             <h4>
#              Discover
#             </h4>
#             <ul>
#              <li>
#               <a href="/search/?ev=em_rs">
#                Explore All
#               </a>
#              </li>
#              <li>
#               <a href="/search/?type=release&amp;sort=hot%2Cdesc&amp;ev=em_tr">
#                Trending Releases
#               </a>
#              </li>
#              <li>
#               <a href="/lists?ev=em_rl">
#                List Explorer
#               </a>
#              </li>
#              <li>
#               <a href="/search/advanced?ev=em_as">
#                Advanced Search
#               </a>
#              </li>
#              <li>
#               <a href="https://blog.discogs.com/en/tag/database-en/?utm_source=discogs&amp;utm_medium=referral&amp;utm_campaign=navigation_menu" target="_blank">
#                Articles About Music
#               </a>
#              </li>
#             </ul>
#            </td>
#            <td>
#             <h4>
#              Contribute
#             </h4>
#             <ul>
#              <li>
#               <a href="https://support.discogs.com/hc/articles/360004016474-Overview-of-Submission-Guidelines-for-Releases/?utm_source=discogs&amp;utm_medium=referral&amp;utm_campaign=navigation_menu" target="_blank">
#                Submission Guidelines
#               </a>
#              </li>
#              <li>
#               <a href="/release/add?ev=em_sr" rel="nofollow">
#                Submit a Release
#               </a>
#              </li>
#              <li>
#               <a href="https://support.discogs.com/hc/articles/360001567973/?utm_source=discogs&amp;utm_medium=referral&amp;utm_campaign=navigation_menu" target="_blank">
#                How to Make a List
#               </a>
#               <li>
#                <a href="/leaderboard">
#                 Monthly Leaderboard
#                </a>
#               </li>
#               <li>
#                <a href="https://localization.discogs.com/?ev=em_bt" target="_blank">
#                 Help Translate Discogs
#                </a>
#               </li>
#              </li>
#             </ul>
#            </td>
#            <td>
#             <div>
#              <h4>
#               Genres
#              </h4>
#              <ul>
#               <li>
#                <a href="/genre/rock?ev=em_rp">
#                 Rock
#                </a>
#               </li>
#               <li>
#                <a href="/genre/electronic?ev=em_ep">
#                 Electronic
#                </a>
#               </li>
#               <li>
#                <a href="/genre/hip+hop?ev=em_pp">
#                 Hip Hop
#                </a>
#               </li>
#               <li>
#                <a href="/genre/folk%2C+world%2C+%26+country?ev=em_fwcp">
#                 Folk, World, &amp; Country
#                </a>
#               </li>
#               <li>
#                <a href="/genre/jazz?ev=em_jp">
#                 Jazz
#                </a>
#               </li>
#              </ul>
#             </div>
#            </td>
#            <td>
#             <div>
#              <h4>
#               Styles
#              </h4>
#              <ul>
#               <li>
#                <a href="/style/house?ev=em_hp">
#                 House
#                </a>
#               </li>
#               <li>
#                <a href="/style/punk?ev=em_pup">
#                 Punk
#                </a>
#               </li>
#               <li>
#                <a href="/style/soul?ev=em_vp">
#                 Soul
#                </a>
#               </li>
#               <li>
#                <a href="https://blog.discogs.com/en/genres-and-styles-list/?utm_source=discogs&amp;utm_medium=referral&amp;utm_campaign=navigation_menu">
#                 Explore All Styles
#                </a>
#               </li>
#               <li>
#                <a href="https://blog.discogs.com/regional-music-styles/">
#                 Regional Style Map
#                </a>
#               </li>
#              </ul>
#             </div>
#            </td>
#           </tr>
#          </table>
#         </div>
#        </li>
#        <li class="site_nav_group" data-id="marketplace" id="section_nav_marketplace">
#         <a aria-label="Toggle Marketplace Menu" class="nav_group_control" href="/sell/list">
#          Marketplace
#          <i class="icon icon-caret-down">
#          </i>
#         </a>
#         <div class="site_nav_submenu site_nav_tray" id="site_nav_tray_marketplace">
#          <table>
#           <tr>
#            <td class="tray_formats">
#             <h4>
#              Format
#             </h4>
#             <ul>
#              <li>
#               <a href="/sell/list?format=Vinyl">
#                Vinyl
#               </a>
#              </li>
#              <li>
#               <a href="/sell/list?format=CD">
#                CD
#               </a>
#              </li>
#              <li>
#               <a href="/sell/list?format=Cassette">
#                Cassette
#               </a>
#              </li>
#              <li>
#               <a href="/sell/list?format=DVD">
#                DVD
#               </a>
#              </li>
#              <li>
#               <a href="/sell/list?format=Box+Set">
#                Box Set
#               </a>
#              </li>
#             </ul>
#            </td>
#            <td class="tray_genres">
#             <h4>
#              Genre
#             </h4>
#             <ul>
#              <li>
#               <a href="/sell/list?genre=Rock">
#                Rock
#               </a>
#              </li>
#              <li>
#               <a href="/sell/list?genre=Electronic">
#                Electronic
#               </a>
#              </li>
#              <li>
#               <a href="/sell/list?genre=Pop">
#                Pop
#               </a>
#              </li>
#              <li>
#               <a href="/sell/list?genre=Funk+%2F+Soul">
#                Funk / Soul
#               </a>
#              </li>
#              <li>
#               <a href="/sell/list?genre=Jazz">
#                Jazz
#               </a>
#              </li>
#             </ul>
#            </td>
#            <td class="tray_styles">
#             <h4>
#              Styles
#             </h4>
#             <ul>
#              <li>
#               <a href="/sell/list?style=Pop+Rock">
#                Pop Rock
#               </a>
#              </li>
#              <li>
#               <a href="/sell/list?style=House">
#                House
#               </a>
#              </li>
#              <li>
#               <a href="/sell/list?style=Disco">
#                Disco
#               </a>
#              </li>
#              <li>
#               <a href="/sell/list?style=Synth-pop">
#                Synth-pop
#               </a>
#              </li>
#              <li>
#               <a href="/sell/list?style=Soul">
#                Soul
#               </a>
#              </li>
#             </ul>
#            </td>
#            <td>
#             <h4>
#              <a href="/sell/list">
#               Buy Music
#              </a>
#             </h4>
#             <ul>
#              <li>
#               <a href="/sell/list">
#                All Items
#               </a>
#              </li>
#              <li>
#               <a href="/sell/mywants">
#                Items I Want
#               </a>
#              </li>
#              <li>
#               <a href="/sell/purchases">
#                Purchases
#               </a>
#              </li>
#              <li>
#               <a href="/sell/cart/">
#                Cart
#               </a>
#              </li>
#              <li>
#               <a href="/record-store-day" target="_blank">
#                Record Stores
#               </a>
#              </li>
#             </ul>
#             <td>
#              <h4>
#               Sell Music
#              </h4>
#              <ul>
#               <li>
#                <a href="/sell/">
#                 List Item For Sale
#                </a>
#               </li>
#               <li>
#                <a href="/sell/orders">
#                 Orders
#                </a>
#               </li>
#               <li>
#                <a href="/sell/manage">
#                 Inventory
#                </a>
#               </li>
#               <li>
#                <a href="/sell/billing">
#                 Billing
#                </a>
#               </li>
#              </ul>
#             </td>
#            </td>
#           </tr>
#          </table>
#         </div>
#        </li>
#        <li class="site_nav_group" data-id="community" id="section_nav_community">
#         <a aria-label="Toggle Community Menu" class="nav_group_control" href="/group/">
#          Community
#          <i class="icon icon-caret-down">
#          </i>
#         </a>
#         <ul class="site_nav_submenu" id="site_nav_submenu_community">
#          <li>
#           <a href="https://www.discogs.com/digs">
#            Discogs Digs
#           </a>
#          </li>
#          <li>
#           <a href="/group/">
#            Groups
#           </a>
#          </li>
#          <li>
#           <a href="/forum/">
#            Forum
#           </a>
#          </li>
#          <li>
#           <a href="https://blog.discogs.com/en/">
#            Blog
#           </a>
#          </li>
#          <li>
#           <a href="/users/friends">
#            Friends
#           </a>
#          </li>
#          <li>
#           <a href="/help/doc/forums">
#            Community Guidelines
#           </a>
#          </li>
#          <li>
#           <a href="https://support.discogs.com/hc/articles/360004016474-Overview-of-Submission-Guidelines-for-Releases">
#            Database Guidelines
#           </a>
#          </li>
#          <li>
#           <a href="https://vinylhub.discogs.com?utm_source=discogs-top-nav&amp;utm_medium=referral" target="_blank">
#            Record Shops
#           </a>
#          </li>
#         </ul>
#        </li>
#       </ul>
#       <ul aria-label="Activity Menu" class="activity_menu_columns_4" id="activity_menu" role="navigation">
#        <li>
#         <a class="button-green button" href="/users/create">
#          Register
#         </a>
#        </li>
#        <li>
#         <a class="nav_group_control" href="/login?return_to=%2Fsearch%2F%3Flimit%3D250%26sort%3Dhave%252Cdesc%26type%3Drelease%26page%3D1" id="log_in_link">
#          Log In
#         </a>
#        </li>
#       </ul>
#       <a aria-label="Open Site Menu" class="" href="#mobile_site_navigation_toggle" id="mobile_site_navigation_toggle">
#        <i class="icon icon-bars">
#        </i>
#       </a>
#       <ul id="mobile_site_navigation">
#        <li id="activity_menu_placeholder">
#        </li>
#        <li id="site_navigation_placeholder">
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#    <div class="ac_div" id="ac_search_q">
#    </div>
#    <div class="flash_messages">
#     <noscript>
#      <div class="alert-message alert-message-warning alert-message-top" data-alert-message-auto-close="false" data-alert-message-closable="false" id="alert-message-">
#       <div class="alert-message-content float_fix">
#        <i class="icon icon-exclamation-triangle alert-message-icon">
#        </i>
#        <span class="alert-message-text">
#         <strong>
#          Please enable Javascript to take full advantage of our site features.
#         </strong>
#        </span>
#       </div>
#      </div>
#     </noscript>
#    </div>
#    <div class="aside_left aside_more_narrow with_tabs aside_off_canvas" id="page">
#     <div class="" id="page_aside" role="complementary">
#      <div class="hide_mobile">
#      </div>
#      <div>
#       <h3 class="facets_header">
#        Genre
#       </h3>
#       <ul class="no_vertical facets_nav">
#        <li>
#         <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Rock">
#          <small class="facet_count">
#           4,979,854
#          </small>
#          <span class="facet_name">
#           Rock
#          </span>
#          <span class="facet-bar" style="width: 33.0840617576629%;">
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Electronic">
#          <small class="facet_count">
#           3,934,812
#          </small>
#          <span class="facet_name">
#           Electronic
#          </span>
#          <span class="facet-bar" style="width: 26.141240930515853%;">
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Pop">
#          <small class="facet_count">
#           2,989,905
#          </small>
#          <span class="facet_name">
#           Pop
#          </span>
#          <span class="facet-bar" style="width: 19.863675053434317%;">
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Folk%2C+World%2C+%26+Country">
#          <small class="facet_count">
#           1,844,470
#          </small>
#          <span class="facet_name">
#           Folk, World, &amp; Country
#          </span>
#          <span class="facet-bar" style="width: 12.253885232409726%;">
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Jazz">
#          <small class="facet_count">
#           1,223,443
#          </small>
#          <span class="facet_name">
#           Jazz
#          </span>
#          <span class="facet-bar" style="width: 8.128042261676823%;">
#          </span>
#         </a>
#        </li>
#       </ul>
#       <a class="more_facets_link" data-for="facets_genre_exact" href="#more_facets_genre_exact">
#        <span class="more_facets_text">
#         All
#         <i class="icon icon-caret-down">
#         </i>
#        </span>
#       </a>
#       <div class="more_facets_dialog" data-title="Genre" id="facets_genre_exact" style="display: none;">
#        <ul class="facets_nav">
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Rock">
#           <small class="facet_count">
#            4,979,854
#           </small>
#           <span class="facet_name">
#            Rock
#           </span>
#           <span class="facet-bar" style="width: 33.0840617576629%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Electronic">
#           <small class="facet_count">
#            3,934,812
#           </small>
#           <span class="facet_name">
#            Electronic
#           </span>
#           <span class="facet-bar" style="width: 26.141240930515853%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Pop">
#           <small class="facet_count">
#            2,989,905
#           </small>
#           <span class="facet_name">
#            Pop
#           </span>
#           <span class="facet-bar" style="width: 19.863675053434317%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Folk%2C+World%2C+%26+Country">
#           <small class="facet_count">
#            1,844,470
#           </small>
#           <span class="facet_name">
#            Folk, World, &amp; Country
#           </span>
#           <span class="facet-bar" style="width: 12.253885232409726%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Jazz">
#           <small class="facet_count">
#            1,223,443
#           </small>
#           <span class="facet_name">
#            Jazz
#           </span>
#           <span class="facet-bar" style="width: 8.128042261676823%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Funk+%2F+Soul">
#           <small class="facet_count">
#            1,046,218
#           </small>
#           <span class="facet_name">
#            Funk / Soul
#           </span>
#           <span class="facet-bar" style="width: 6.950633678011156%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Classical">
#           <small class="facet_count">
#            904,046
#           </small>
#           <span class="facet_name">
#            Classical
#           </span>
#           <span class="facet-bar" style="width: 6.006102527457254%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Hip+Hop">
#           <small class="facet_count">
#            763,078
#           </small>
#           <span class="facet_name">
#            Hip Hop
#           </span>
#           <span class="facet-bar" style="width: 5.0695702480261255%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Latin">
#           <small class="facet_count">
#            616,654
#           </small>
#           <span class="facet_name">
#            Latin
#           </span>
#           <span class="facet-bar" style="width: 4.0967905924771815%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Stage+%26+Screen">
#           <small class="facet_count">
#            433,615
#           </small>
#           <span class="facet_name">
#            Stage &amp; Screen
#           </span>
#           <span class="facet-bar" style="width: 2.880756230815%;">
#           </span>
#          </a>
#         </li>
#        </ul>
#        <ul class="facets_nav">
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Reggae">
#           <small class="facet_count">
#            381,339
#           </small>
#           <span class="facet_name">
#            Reggae
#           </span>
#           <span class="facet-bar" style="width: 2.533456407879712%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Blues">
#           <small class="facet_count">
#            325,782
#           </small>
#           <span class="facet_name">
#            Blues
#           </span>
#           <span class="facet-bar" style="width: 2.1643589967768%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Non-Music">
#           <small class="facet_count">
#            289,936
#           </small>
#           <span class="facet_name">
#            Non-Music
#           </span>
#           <span class="facet-bar" style="width: 1.9262132041962983%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Children%27s">
#           <small class="facet_count">
#            132,467
#           </small>
#           <span class="facet_name">
#            Children's
#           </span>
#           <span class="facet-bar" style="width: 0.880055200183044%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Brass+%26+Military">
#           <small class="facet_count">
#            51,155
#           </small>
#           <span class="facet_name">
#            Brass &amp; Military
#           </span>
#           <span class="facet-bar" style="width: 0.33985236900785565%;">
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <h3 class="facets_header">
#        Style
#       </h3>
#       <ul class="no_vertical facets_nav">
#        <li>
#         <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Pop+Rock">
#          <small class="facet_count">
#           767,138
#          </small>
#          <span class="facet_name">
#           Pop Rock
#          </span>
#          <span class="facet-bar" style="width: 5.096543185533151%;">
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=House">
#          <small class="facet_count">
#           593,264
#          </small>
#          <span class="facet_name">
#           House
#          </span>
#          <span class="facet-bar" style="width: 3.94139724068178%;">
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Vocal">
#          <small class="facet_count">
#           502,401
#          </small>
#          <span class="facet_name">
#           Vocal
#          </span>
#          <span class="facet-bar" style="width: 3.337741570558414%;">
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Experimental">
#          <small class="facet_count">
#           490,978
#          </small>
#          <span class="facet_name">
#           Experimental
#          </span>
#          <span class="facet-bar" style="width: 3.2618519486020707%;">
#          </span>
#         </a>
#        </li>
#        <li>
#         <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Punk">
#          <small class="facet_count">
#           466,040
#          </small>
#          <span class="facet_name">
#           Punk
#          </span>
#          <span class="facet-bar" style="width: 3.096174333934533%;">
#          </span>
#         </a>
#        </li>
#       </ul>
#       <a class="more_facets_link" data-for="facets_style_exact" href="#more_facets_style_exact">
#        <span class="more_facets_text">
#         All
#         <i class="icon icon-caret-down">
#         </i>
#        </span>
#       </a>
#       <div class="more_facets_dialog" data-title="Style" id="facets_style_exact" style="display: none;">
#        <ul class="facets_nav">
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Pop+Rock">
#           <small class="facet_count">
#            767,138
#           </small>
#           <span class="facet_name">
#            Pop Rock
#           </span>
#           <span class="facet-bar" style="width: 5.096543185533151%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=House">
#           <small class="facet_count">
#            593,264
#           </small>
#           <span class="facet_name">
#            House
#           </span>
#           <span class="facet-bar" style="width: 3.94139724068178%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Vocal">
#           <small class="facet_count">
#            502,401
#           </small>
#           <span class="facet_name">
#            Vocal
#           </span>
#           <span class="facet-bar" style="width: 3.337741570558414%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Experimental">
#           <small class="facet_count">
#            490,978
#           </small>
#           <span class="facet_name">
#            Experimental
#           </span>
#           <span class="facet-bar" style="width: 3.2618519486020707%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Punk">
#           <small class="facet_count">
#            466,040
#           </small>
#           <span class="facet_name">
#            Punk
#           </span>
#           <span class="facet-bar" style="width: 3.096174333934533%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Synth-pop">
#           <small class="facet_count">
#            442,681
#           </small>
#           <span class="facet_name">
#            Synth-pop
#           </span>
#           <span class="facet-bar" style="width: 2.9409869331398015%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Alternative+Rock">
#           <small class="facet_count">
#            423,013
#           </small>
#           <span class="facet_name">
#            Alternative Rock
#           </span>
#           <span class="facet-bar" style="width: 2.8103209885860627%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Techno">
#           <small class="facet_count">
#            389,565
#           </small>
#           <span class="facet_name">
#            Techno
#           </span>
#           <span class="facet-bar" style="width: 2.5881065024444387%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Disco">
#           <small class="facet_count">
#            375,474
#           </small>
#           <span class="facet_name">
#            Disco
#           </span>
#           <span class="facet-bar" style="width: 2.4944918072691933%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Soul">
#           <small class="facet_count">
#            366,205
#           </small>
#           <span class="facet_name">
#            Soul
#           </span>
#           <span class="facet-bar" style="width: 2.4329124580690404%;">
#           </span>
#          </a>
#         </li>
#        </ul>
#        <ul class="facets_nav">
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Indie+Rock">
#           <small class="facet_count">
#            357,976
#           </small>
#           <span class="facet_name">
#            Indie Rock
#           </span>
#           <span class="facet-bar" style="width: 2.378242432762313%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Hardcore">
#           <small class="facet_count">
#            337,763
#           </small>
#           <span class="facet_name">
#            Hardcore
#           </span>
#           <span class="facet-bar" style="width: 2.243955736745193%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Ambient">
#           <small class="facet_count">
#            336,176
#           </small>
#           <span class="facet_name">
#            Ambient
#           </span>
#           <span class="facet-bar" style="width: 2.233412374227053%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Folk">
#           <small class="facet_count">
#            315,636
#           </small>
#           <span class="facet_name">
#            Folk
#           </span>
#           <span class="facet-bar" style="width: 2.096953227331903%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Hard+Rock">
#           <small class="facet_count">
#            305,638
#           </small>
#           <span class="facet_name">
#            Hard Rock
#           </span>
#           <span class="facet-bar" style="width: 2.0305307078256862%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Ballad">
#           <small class="facet_count">
#            291,182
#           </small>
#           <span class="facet_name">
#            Ballad
#           </span>
#           <span class="facet-bar" style="width: 1.934491105707075%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Country">
#           <small class="facet_count">
#            287,392
#           </small>
#           <span class="facet_name">
#            Country
#           </span>
#           <span class="facet-bar" style="width: 1.9093119349800731%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Electro">
#           <small class="facet_count">
#            285,989
#           </small>
#           <span class="facet_name">
#            Electro
#           </span>
#           <span class="facet-bar" style="width: 1.8999909913046158%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Rock+%26+Roll">
#           <small class="facet_count">
#            267,838
#           </small>
#           <span class="facet_name">
#            Rock &amp; Roll
#           </span>
#           <span class="facet-bar" style="width: 1.7794033586223446%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Chanson">
#           <small class="facet_count">
#            251,215
#           </small>
#           <span class="facet_name">
#            Chanson
#           </span>
#           <span class="facet-bar" style="width: 1.668967117198875%;">
#           </span>
#          </a>
#         </li>
#        </ul>
#        <ul class="facets_nav">
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Trance">
#           <small class="facet_count">
#            245,681
#           </small>
#           <span class="facet_name">
#            Trance
#           </span>
#           <span class="facet-bar" style="width: 1.6322015417890527%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Heavy+Metal">
#           <small class="facet_count">
#            241,307
#           </small>
#           <span class="facet_name">
#            Heavy Metal
#           </span>
#           <span class="facet-bar" style="width: 1.6031425199526657%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Psychedelic+Rock">
#           <small class="facet_count">
#            230,898
#           </small>
#           <span class="facet_name">
#            Psychedelic Rock
#           </span>
#           <span class="facet-bar" style="width: 1.5339894887924124%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Classic+Rock">
#           <small class="facet_count">
#            221,339
#           </small>
#           <span class="facet_name">
#            Classic Rock
#           </span>
#           <span class="facet-bar" style="width: 1.4704835011989006%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Folk+Rock">
#           <small class="facet_count">
#            220,851
#           </small>
#           <span class="facet_name">
#            Folk Rock
#           </span>
#           <span class="facet-bar" style="width: 1.4672414338335242%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Downtempo">
#           <small class="facet_count">
#            216,835
#           </small>
#           <span class="facet_name">
#            Downtempo
#           </span>
#           <span class="facet-bar" style="width: 1.4405608138758357%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Soundtrack">
#           <small class="facet_count">
#            207,692
#           </small>
#           <span class="facet_name">
#            Soundtrack
#           </span>
#           <span class="facet-bar" style="width: 1.379818555839694%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Noise">
#           <small class="facet_count">
#            206,546
#           </small>
#           <span class="facet_name">
#            Noise
#           </span>
#           <span class="facet-bar" style="width: 1.372205012395593%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Prog+Rock">
#           <small class="facet_count">
#            204,866
#           </small>
#           <span class="facet_name">
#            Prog Rock
#           </span>
#           <span class="facet-bar" style="width: 1.3610437968754443%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Romantic">
#           <small class="facet_count">
#            201,387
#           </small>
#           <span class="facet_name">
#            Romantic
#           </span>
#           <span class="facet-bar" style="width: 1.3379307797358033%;">
#           </span>
#          </a>
#         </li>
#        </ul>
#        <hr/>
#        <ul class="facets_nav">
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Schlager">
#           <small class="facet_count">
#            196,472
#           </small>
#           <span class="facet_name">
#            Schlager
#           </span>
#           <span class="facet-bar" style="width: 1.3052775807587023%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Funk">
#           <small class="facet_count">
#            196,351
#           </small>
#           <span class="facet_name">
#            Funk
#           </span>
#           <span class="facet-bar" style="width: 1.3044737074980248%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Easy+Listening">
#           <small class="facet_count">
#            182,713
#           </small>
#           <span class="facet_name">
#            Easy Listening
#           </span>
#           <span class="facet-bar" style="width: 1.213868554364819%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Tech+House">
#           <small class="facet_count">
#            172,820
#           </small>
#           <span class="facet_name">
#            Tech House
#           </span>
#           <span class="facet-bar" style="width: 1.1481436108286114%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Blues+Rock">
#           <small class="facet_count">
#            170,200
#           </small>
#           <span class="facet_name">
#            Blues Rock
#           </span>
#           <span class="facet-bar" style="width: 1.130737429481713%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Black+Metal">
#           <small class="facet_count">
#            168,232
#           </small>
#           <span class="facet_name">
#            Black Metal
#           </span>
#           <span class="facet-bar" style="width: 1.117662862729539%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=New+Wave">
#           <small class="facet_count">
#            167,724
#           </small>
#           <span class="facet_name">
#            New Wave
#           </span>
#           <span class="facet-bar" style="width: 1.1142879237508274%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Rhythm+%26+Blues">
#           <small class="facet_count">
#            160,859
#           </small>
#           <span class="facet_name">
#            Rhythm &amp; Blues
#           </span>
#           <span class="facet-bar" style="width: 1.068679742473554%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Deep+House">
#           <small class="facet_count">
#            159,416
#           </small>
#           <span class="facet_name">
#            Deep House
#           </span>
#           <span class="facet-bar" style="width: 1.0590930555714262%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Industrial">
#           <small class="facet_count">
#            158,035
#           </small>
#           <span class="facet_name">
#            Industrial
#           </span>
#           <span class="facet-bar" style="width: 1.0499182706706376%;">
#           </span>
#          </a>
#         </li>
#        </ul>
#        <ul class="facets_nav">
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Euro+House">
#           <small class="facet_count">
#            152,094
#           </small>
#           <span class="facet_name">
#            Euro House
#           </span>
#           <span class="facet-bar" style="width: 1.0104487579294457%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Progressive+House">
#           <small class="facet_count">
#            148,951
#           </small>
#           <span class="facet_name">
#            Progressive House
#           </span>
#           <span class="facet-bar" style="width: 0.9895679838938345%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Death+Metal">
#           <small class="facet_count">
#            147,247
#           </small>
#           <span class="facet_name">
#            Death Metal
#           </span>
#           <span class="facet-bar" style="width: 0.9782473224376839%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Drum+n+Bass">
#           <small class="facet_count">
#            145,898
#           </small>
#           <span class="facet_name">
#            Drum n Bass
#           </span>
#           <span class="facet-bar" style="width: 0.9692851321182312%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Classical">
#           <small class="facet_count">
#            144,429
#           </small>
#           <span class="facet_name">
#            Classical
#           </span>
#           <span class="facet-bar" style="width: 0.9595257121187681%;">
#           </span>
#          </a>
#         </li>
#         <li>
#          <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Soft+Rock">
# ...
#           <i class="icon icon-collection">
#           </i>
#           <span class="count">
#            0
#           </span>
#          </span>
#          <span aria-label="0 in Wantlist" class="skittle skittle_wantlist needs_delegated_tooltip" data-title="0 in Wantlist" style="display: none;" title="0 in Wantlist">
#           <i class="icon icon-wantlist">
#           </i>
#           <span class="count">
#            0
#           </span>
#          </span>
#          <a aria-label="0 in Inventory" class="skittle skittle_inventory needs_delegated_tooltip" data-title="0 in Inventory" href="/sell/release/413315?seller=Anonymous" style="display: none;" title="0 in Inventory">
#           <i class="icon icon-store">
#           </i>
#           <span class="count">
#            0
#           </span>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="pagination bottom">
#        <form action="/search/" data-section="general" method="get">
#         <strong class="pagination_total">
#          1 – 250 of 15,052,124
#         </strong>
#         <div class="responsive_wrap">
#          <ul class="pagination_page_links">
#           <li>
#            <span>
#             <i class="icon icon-chevron-left">
#             </i>
#             Prev
#            </span>
#           </li>
#           <li>
#            <a class="pagination_next" href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=2">
#             Next
#             <i class="icon icon-chevron-right">
#             </i>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="pagination_controls multiple_filters">
#          <label class="hide_mobile" for="limit_bottom">
#           Show
#          </label>
#          <select class="hide_mobile" id="limit_bottom" name="limit">
#           <option value="25">
#            25
#           </option>
#           <option value="50">
#            50
#           </option>
#           <option value="100">
#            100
#           </option>
#           <option selected="selected" value="250">
#            250
#           </option>
#          </select>
#          <noscript>
#           <button type="submit">
#            Refresh
#           </button>
#          </noscript>
#         </div>
#         <input name="sort" type="hidden" value="have,desc"/>
#         <input name="type" type="hidden" value="release"/>
#        </form>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="sticky_footer">
#     <button id="move">
#      <i class="icon icon-close">
#      </i>
#     </button>
#     <div class="ad_container ad_bottom" id="ad_bottom">
#     </div>
#    </div>
#    <div id="push_footer">
#    </div>
#   </div>
#   <div id="site_footer_wrap">
#    <div aria-label="Footer Navigation" id="site_footer" role="navigation">
#     <div class="banner_ad pub_300x250 pub_300x250m pub_728x90 text-ad textAd text_ad text_ads text-ads text-ad-links">
#     </div>
#     <ul id="site_footer_list">
#      <li>
#       <h5>
#        Discogs
#       </h5>
#       <ul>
#        <li>
#         <a href="https://www.discogs.com/company">
#          About Us
#         </a>
#        </li>
#        <li>
#         <a href="https://blog.discogs.com/en/">
#          Blog
#         </a>
#        </li>
#        <li>
#         <a href="/app">
#          App
#         </a>
#        </li>
#        <li>
#         <a href="https://www.discogs.com/company/careers">
#          Careers
#         </a>
#        </li>
#        <li>
#         <a href="/developers">
#          API
#         </a>
#        </li>
#        <li>
#         <a href="https://blog.discogs.com/en/tag/engineering-en/">
#          Change Log
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li>
#       <h5>
#        Help Is Here
#       </h5>
#       <ul>
#        <li>
#         <a href="https://support.discogs.com">
#          Help &amp; Support
#         </a>
#        </li>
#        <li>
#         <a href="/forum/">
#          Forum
#         </a>
#        </li>
#        <li>
#         <a class="show_keyboard_shortcuts" href="#show_keyboard_shortcuts">
#          Keyboard Shortcuts
#         </a>
#        </li>
#        <li>
#         <a href="https://support.discogs.com/hc/articles/360004016474-Overview-of-Submission-Guidelines-for-Releases">
#          Database Guidelines
#         </a>
#        </li>
#        <li>
#         <a href="/shipping">
#          Discogs Shipping
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li>
#       <h5>
#        Join In
#       </h5>
#       <ul>
#        <li>
#         <a href="/getstarted/">
#          Get Started
#         </a>
#        </li>
#        <li>
#         <a href="/users/create">
#          Sign Up
#         </a>
#        </li>
#        <li>
#         <a href="https://www.discogs.com/digs">
#          Discogs Digs
#         </a>
#        </li>
#        <li>
#         <a href="/help/doc/contributing">
#          Contribute
#         </a>
#        </li>
#        <li>
#         <a href="/release/add">
#          Add Release
#         </a>
#        </li>
#        <li>
#         <a href="/stats/contributors">
#          Contributor List
#         </a>
#        </li>
#        <li>
#         <a href="https://support.discogs.com/hc/articles/360001585814-How-Can-I-Help-Translate-Discogs-">
#          Help Translate
#         </a>
#        </li>
#        <li>
#         <a href="/record-store-day">
#          Record Stores
#         </a>
#        </li>
#        <li>
#         <a href="/cdn-cgi/l/email-protection#aad9cbc6cfd9eacec3d9c9c5cdd984c9c5c7">
#          Advertise With Us
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li>
#       <h5>
#        Follow Us
#       </h5>
#       <ul>
#        <li>
#         <a href="https://www.facebook.com/discogs">
#          <i class="icon icon-facebook-square">
#          </i>
#          Facebook
#         </a>
#        </li>
#        <li>
#         <a href="https://twitter.com/discogs">
#          <i class="icon icon-twitter">
#          </i>
#          Twitter
#         </a>
#        </li>
#        <li>
#         <a href="https://youtube.com/discogs">
#          <i class="icon icon-youtube">
#          </i>
#          YouTube
#         </a>
#        </li>
#        <li>
#         <a href="https://www.instagram.com/discogs/">
#          <i class="icon icon-instagram">
#          </i>
#          Instagram
#         </a>
#        </li>
#        <li>
#         <a href="http://www.mixcloud.com/discogs/">
#          <i class="icon icon-mixcloud">
#          </i>
#          Mixcloud
#         </a>
#        </li>
#        <li>
#         <a href="https://soundcloud.com/discogs">
#          <i class="icon icon-soundcloud">
#          </i>
#          Soundcloud
#         </a>
#        </li>
#        <li>
#         <a href="https://www.pinterest.com/officialdiscogs/">
#          <i class="icon icon-pinterest">
#          </i>
#          Pinterest
#         </a>
#        </li>
#       </ul>
#      </li>
#     </ul>
#    </div>
#    <div id="site_footer_legal">
#     <div>
#      <img alt="" src="https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/images/discogs-white.png?5"/>
#      <span id="copyright">
#       © 2022 Discogs®
#      </span>
#      <button class="ot-sdk-show-settings" id="ot-sdk-btn">
#       Cookie Settings
#      </button>
#      <a href="/help/doc/cookie-policy" id="cookie_link">
#       Cookie Policy
#      </a>
#      <a href="/help/doc/terms-of-service" id="terms_link">
#       Terms of Service
#      </a>
#      <a href="/help/doc/privacy-policy" id="privacy_link">
#       Privacy Policy
#      </a>
#      <a href="https://support.discogs.com/hc/articles/360039846494-California-Privacy-Notice">
#       California Privacy Notice
#      </a>
#      <a href="https://support.discogs.com/hc/en-us/articles/360017786278-Accessibility-Statement" target="_blank">
#       Accessibility Statement
#      </a>
#      <span id="language_container">
#       <a data-code="en" data-name="English" href="#select-language" id="i18n_link">
#        <i class="icon icon-globe">
#        </i>
#        English
#        <i class="icon icon-caret-down">
#        </i>
#       </a>
#       <select id="i18n_select">
#        <option class="language" id="language_de_field" name="language_code" value="de">
#         Deutsch
#        </option>
#        <option class="language" id="language_en_field" name="language_code" selected="" value="en">
#         English
#        </option>
#        <option class="language" id="language_es_field" name="language_code" value="es">
#         Español
#        </option>
#        <option class="language" id="language_fr_field" name="language_code" value="fr">
#         Français
#        </option>
#        <option class="language" id="language_it_field" name="language_code" value="it">
#         Italiano
#        </option>
#        <option class="language" id="language_ja_field" name="language_code" value="ja">
#         日本語
#        </option>
#        <option class="language" id="language_ko_field" name="language_code" value="ko">
#         한국어
#        </option>
#        <option class="language" id="language_pt_BR_field" name="language_code" value="pt_BR">
#         Português (Brasil)
#        </option>
#        <option class="language" id="language_ru_field" name="language_code" value="ru">
#         Русский
#        </option>
#       </select>
#      </span>
#      <a id="footer_menu_link">
#       <i class="icon icon-chevron-down">
#       </i>
#       <i class="icon icon-chevron-up">
#       </i>
#      </a>
#     </div>
#    </div>
#   </div>
#   <div id="act">
#   </div>
#   <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js">
#   </script>
#   <script type="text/javascript">
#    !function(){"use strict";function a(a){return"function"==typeof a||"object"==typeof a&&null!==a}function b(a){return"function"==typeof a}function c(a){return"object"==typeof a&&null!==a}function g(){}function n(){return function(){process.nextTick(s)}}function o(){var a=0,b=new l(s),c=document.createTextNode("");return b.observe(c,{characterData:!0}),function(){c.data=a=++a%2}}function p(){var a=new MessageChannel;return a.port1.onmessage=s,function(){a.port2.postMessage(0)}}function q(){return function(){setTimeout(s,1)}}function s(){for(var a=0;i>a;a+=2){var b=r[a],c=r[a+1];b(c),r[a]=void 0,r[a+1]=void 0}i=0}function u(){}function z(){return new TypeError("You cannot resolve a promise with itself")}function A(){return new TypeError("A promises callback cannot return that same promise.")}function B(a){try{return a.then}catch(b){return y.error=b,y}}function C(a,b,c,d){try{a.call(b,c,d)}catch(e){return e}}function D(a,b,c){j(function(a){var d=!1,e=C(c,b,function(c){d||(d=!0,b!==c?G(a,c):I(a,c))},function(b){d||(d=!0,J(a,b))},"Settle: "+(a._label||" unknown promise"));!d&&e&&(d=!0,J(a,e))},a)}function E(a,b){b._state===w?I(a,b._result):a._state===x?J(a,b._result):K(b,void 0,function(b){G(a,b)},function(b){J(a,b)})}function F(a,c){if(c.constructor===a.constructor)E(a,c);else{var d=B(c);d===y?J(a,y.error):void 0===d?I(a,c):b(d)?D(a,c,d):I(a,c)}}function G(b,c){b===c?J(b,z()):a(c)?F(b,c):I(b,c)}function H(a){a._onerror&&a._onerror(a._result),L(a)}function I(a,b){a._state===v&&(a._result=b,a._state=w,0===a._subscribers.length||j(L,a))}function J(a,b){a._state===v&&(a._state=x,a._result=b,j(H,a))}function K(a,b,c,d){var e=a._subscribers,f=e.length;a._onerror=null,e[f]=b,e[f+w]=c,e[f+x]=d,0===f&&a._state&&j(L,a)}function L(a){var b=a._subscribers,c=a._state;if(0!==b.length){for(var d,e,f=a._result,g=0;g<b.length;g+=3)d=b[g],e=b[g+c],d?P(c,d,e,f):e(f);a._subscribers.length=0}}function M(){this.error=null}function O(a,b){try{return a(b)}catch(c){return N.error=c,N}}function P(a,c,d,e){var g,h,i,j,f=b(d);if(f){if(g=O(d,e),g===N?(j=!0,h=g.error,g=null):i=!0,c===g)return J(c,A()),void 0}else g=e,i=!0;c._state!==v||(f&&i?G(c,g):j?J(c,h):a===w?I(c,g):a===x&&J(c,g))}function Q(a,b){try{b(function(b){G(a,b)},function(b){J(a,b)})}catch(c){J(a,c)}}function S(a,b,c,d){this._instanceConstructor=a,this.promise=new a(u,d),this._abortOnReject=c,this._validateInput(b)?(this._input=b,this.length=b.length,this._remaining=b.length,this._init(),0===this.length?I(this.promise,this._result):(this.length=this.length||0,this._enumerate(),0===this._remaining&&I(this.promise,this._result))):J(this.promise,this._validationError())}function Z(){throw new TypeError("You must pass a resolver function as the first argument to the promise constructor")}function $(){throw new TypeError("Failed to construct 'Promise': Please use the 'new' operator, this object constructor cannot be called as a function.")}function ab(a,c){this._id=Y++,this._label=c,this._state=void 0,this._result=void 0,this._subscribers=[],u!==a&&(b(a)||Z(),this instanceof ab||$(),Q(this,a))}var d;d=Array.isArray?Array.isArray:function(a){return"[object Array]"===Object.prototype.toString.call(a)};var e=d;Date.now||function(){return(new Date).getTime()},Object.create||function(a){if(arguments.length>1)throw new Error("Second argument not supported");if("object"!=typeof a)throw new TypeError("Argument must be an object");return g.prototype=a,new g};var t,i=0,j=function(a,b){r[i]=a,r[i+1]=b,i+=2,2===i&&t()},k="undefined"!=typeof window?window:{},l=k.MutationObserver||k.WebKitMutationObserver,m="undefined"!=typeof Uint8ClampedArray&&"undefined"!=typeof importScripts&&"undefined"!=typeof MessageChannel,r=new Array(1e3);t="undefined"!=typeof process&&"[object process]"==={}.toString.call(process)?n():l?o():m?p():q();var v=void 0,w=1,x=2,y=new M,N=new M;S.prototype._validateInput=function(a){return e(a)},S.prototype._validationError=function(){return new Error("Array Methods must be provided an Array")}, ...
#
# ES6Promise.polyfill();
#   </script>
#   <!--[if lte IE 9]>    <script src="https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/dst/javascripts/vendor.js"></script>
#     <script src="https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/dst/javascripts/discogs.js"></script>
#     <script src="https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/dst/javascripts/sections/search.js"></script>
# <script>ds.require('app')</script>
# <script>ds.require('googleTagServices');</script><![endif]-->
#   <!--[if gt IE 9]><!-->
#   <script>
#    (function(scripts){
#
#     var i = -1, l = scripts.length - 1;
#     var startTime = new Date().getTime();
#     var _scripts  = [];
#     var loads     = [];
#     var j;
#
#     var head = document.head || document.getElementsByTagName('head')[0];
#
#     function log(){
#         window.console && console.log && console.log.apply(console, arguments);
#     }
#
#     function makeScript(src){
#         var element  = document.createElement('script');
#         var isVendor = !!src.match(/javascripts\/(vendor|react-bundle)/);
#         var isSync   = !!(src.match('javascripts/define.js') || src.match('discogs.js') || src.match('moment-lib.js'));
#         var isAsync  = !(isVendor || isSync);
#         var load     = new Promise(function(resolve){
#             element.onload = function(){ resolve(src); };
#             element.src = src;
#             element.setAttribute('defer', 'defer');
#             if (isAsync) {
#                 element.setAttribute('async', 'async');
#             }
#         });
#         _scripts.push({ element: element, load: load, isAsync: isAsync });
#     }
#
#     for (j = 0; j <= l; j++) {
#         makeScript(scripts[j]);
#     }
#
#     for (j = 0; j <= l; j++) {
#         loads.push(_scripts[j].load);
#     }
#
#     Promise.all(loads).then(function(urls){
#                 var app = ds.require('app');
#             });
#
#     function loadNext(){
#         i++;
#         var script = _scripts[i];
#         if (script) {
#             head.appendChild(script.element);
#             if (script.isAsync) {
#                 loadNext();
#             } else {
#                 script.load.then(loadNext);
#             }
#         }
#     }
#
#     loadNext();
#
# })(["https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/dst/javascripts/vendor.js", "https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/dst/javascripts/discogs.js", "https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/dst/javascripts/sections/search.js"]);
#   </script>
#   <!--<![endif]-->
#   <script>
#    ds(function(require){
#     require("search");
#     require("pagination");
# });
#   </script>
#  </body>
# </html>

# %%
#"https://www.discogs.com/search/?limit=250&sort=have%2Cdesc&type=release&page=1
#https://www.discogs.com/search/?limit=250&sort=have%2Cdesc&type=release&page=2
#https://www.discogs.com/search/?limit=250&sort=have%2Cdesc&type=release&page=3

# %%
#URL iterations - 8 pages total 

iterations = range(1, 9, 1)

for i in iterations:
    page = str(i)
    url = "https://www.discogs.com/search/?limit=250&sort=have%2Cdesc&type=release&page=" + page 
    print(url)
# Out:
# https://www.discogs.com/search/?limit=250&sort=have%2Cdesc&type=release&page=1
# https://www.discogs.com/search/?limit=250&sort=have%2Cdesc&type=release&page=2
# https://www.discogs.com/search/?limit=250&sort=have%2Cdesc&type=release&page=3
# https://www.discogs.com/search/?limit=250&sort=have%2Cdesc&type=release&page=4
# https://www.discogs.com/search/?limit=250&sort=have%2Cdesc&type=release&page=5
# https://www.discogs.com/search/?limit=250&sort=have%2Cdesc&type=release&page=6
# https://www.discogs.com/search/?limit=250&sort=have%2Cdesc&type=release&page=7
# https://www.discogs.com/search/?limit=250&sort=have%2Cdesc&type=release&page=8

# %% [markdown]
# Respectful scraping:
#
# Before starting with the actual scraping, though, there's something we need to note when sending massive, automated requests to websites: it's rude.
#
# We just have 13 of them, which is not too many, but it's still a good practice to let a few seconds pass in between requests. Some pages don't like being scraped and will block your IP if they detect it's sending automated requests. Others might have a small server for the traffic they handle, and sending too many requests might crash the site.
#
# The sleep module will help us with that.
#
# We will now scrape all the pages and store the response into a list - waiting a few seconds in between requests:

# %%
# To make it more "human", we can randomize the waiting time:
from time import sleep
from random import randint

pages = []

for i in range(1, 9, 1):

    # assemble the url:
    page = str(i)
    url = "https://www.discogs.com/search/?limit=250&sort=have%2Cdesc&type=release&page=" + page 

    # download html with a get request:
    response = requests.get(url)

    # monitor the process by printing the status code
    print("Status code: " + str(response.status_code))

    # store response into "pages" list
    pages.append(response)

    # respectful nap:
    wait_time = randint(1,6)
    print("I will sleep for " + str(wait_time) + " second/s.")
    sleep(wait_time)
# Out:
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 4 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 3 second/s.
# Status code: 200
# I will sleep for 1 second/s.
# Status code: 200
# I will sleep for 5 second/s.

# %% [markdown]
# Note how if you print the object pages after running the code above, you'll just see the response code messages, but the html code is still accessible and you can parse it the same way we've always done:

# %%
for i in range(1, 8, 1):
    BeautifulSoup(pages[i].content, "html.parser")

# %%
soup_1 = BeautifulSoup(pages[0].content, "html.parser")
soup_2 = BeautifulSoup(pages[1].content, "html.parser")
soup_3 = BeautifulSoup(pages[2].content, "html.parser")
soup_4 = BeautifulSoup(pages[3].content, "html.parser")
soup_5 = BeautifulSoup(pages[4].content, "html.parser")
soup_6 = BeautifulSoup(pages[5].content, "html.parser")
soup_7 = BeautifulSoup(pages[6].content, "html.parser")
soup_8 = BeautifulSoup(pages[7].content, "html.parser")

# %%
print(soup_1)
# Out:
# <!DOCTYPE html>
#
# <html class="is_not_mobile needs_reduced_ui" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="en" http-equiv="content-language"/>
# <meta content="no-cache" http-equiv="pragma">
# <meta content="-1" http-equiv="expires">
# <!-- OT will rewrite convert these to javascript and update our consent module accordingly -->
# <script class="optanon-category-C0002" type="text/plain">
#             window.consent.resolveGroup(window.consent.PERFORMANCE_GROUP)
#         </script>
# <script class="optanon-category-C0003" type="text/plain">
#             window.consent.resolveGroup(window.consent.FUNCTIONALITY_GROUP)
#         </script>
# <script class="optanon-category-C0004" type="text/plain">
#             window.consent.resolveGroup(window.consent.TARGETING_GROUP)
#         </script>
# <meta content="initial-scale=1.0,width=device-width" id="viewport" name="viewport">
# <script>
#             if (window.innerWidth <= 600) document.getElementById('viewport').setAttribute('content', 'initial-scale=1.0, minimum-scale 1.0, width="device-width"');
#                                             </script>
# <script type="text/javascript">
#             window.__start = new Date().getTime();
#         </script>
# <script type="text/javascript">
#             // dataLayer additions consumed by Google Tag Manager for later submission
#             // to Google Analytics - this object is added to _every_ page.
#             window.dataLayer = window.dataLayer || [];
#             window.dataLayer.push({
#                 'event': 'dataLayer-initialized',
#                 'userId': undefined,
#                 'loggedIn': false,
#                 'siteVersion': undefined,
#                 'pageCategory': "search.query"
#             });
#         </script>
# <meta content="Discover music on Discogs, the largest online music database. Buy and sell music with collectors in the Marketplace." name="description"/>
# <meta content="vinyl records, used cds, discography, database, new, used, cds, lps, vinyl record, albums, rare cds, rare records, music albums, music cds, cd single, music cd, cd singles, rare lps, hard to find music, out of print music, cheap cds, cheap music, rare vinyl records, used music" name="keywords"/>
# <meta content="117175028305858" property="fb:app_id"/> <meta content="noindex, nofollow" name="robots">
# <script src="https://lngtd.com/discogs_b.js" type="text/javascript"></script>
# <title>Find Music on Discogs | Discogs</title>
# <link id="rel_next" rel="next" url="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=2"/>
# <link href="https://www.discogs.com/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1" hreflang="en" rel="alternate">
# <link href="https://www.discogs.com/de/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1" hreflang="de" rel="alternate"/>
# <link href="https://www.discogs.com/es/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1" hreflang="es" rel="alternate"/>
# <link href="https://www.discogs.com/fr/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1" hreflang="fr" rel="alternate"/>
# <link href="https://www.discogs.com/it/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1" hreflang="it" rel="alternate"/>
# <link href="https://www.discogs.com/ja/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1" hreflang="ja" rel="alternate"/>
# <link href="https://www.discogs.com/ko/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1" hreflang="ko" rel="alternate"/>
# <link href="https://www.discogs.com/pt_BR/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1" hreflang="pt-BR" rel="alternate"/>
# <link href="https://www.discogs.com/ru/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1" hreflang="ru" rel="alternate"/>
# <link href="https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/dst/stylesheets/discogs.css" rel="stylesheet" type="text/css"/>
# <link href="https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/images/favicon.ico" rel="icon"/>
# <link href="https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/images/favicon-16x16.png" rel="icon" sizes="16x16"/>
# <link href="https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/images/favicon-32x32.png" rel="icon" sizes="32x32"/>
# <link href="https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/images/favicon-96x96.png" rel="icon" sizes="96x96"/>
# <link href="https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/images/apple-touch-icon-precomposed.png" rel="apple-touch-icon"/>
# <link color="black" href="https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/images/discogs-record-icon.svg" rel="mask-icon"/>
# <script id="dsdata">
#             function dsdata (){
#                 return {"activationHelpUrl": "/help/doc/activation", "apiServer": "https://api.discogs.com", "appEnv": "production", "assetBasePath": "53735943f116d10c83937e2c850ad367a600ecc9/dst/", "assetsHost": "https://s.discogs.com/", "autocompleteUrl": "/search/ac", "cookieDomain": "www.discogs.com", "countryAbbr": "gb", "countryName": "United Kingdom", "dataLayer": [], "defaultLocale": "en", "enableGaDebugging": false, "enableGaDebuggingVerbose": false, "enableGoogleAnalytics": true, "endpoint": "search.query", "ga_pageview_page": "/home", "ga_pageview_title": "home", "isDiscogsApp": false, "isMobile": false, "locale": "en", "loginUrl": "https://www.discogs.com/login", "mp_web": {"cart_anon": true}, "recaptchaKey": "6LdGMgITAAAAAPG6lAC5r1yck_LpHUbQs4IbnNtV", "requireCookieConsent": true, "sentryKey": "https://387a0c015e78429ca256c602993e2b92@sentry.io/51758", "sha": "53735943f116d10c83937e2c850ad367a600ecc9", "useSentry": true, "userIsAdmin": false, "userIsRegistered": false, "searchQuery": "", "pagination_limit": 250, "searchTotal": 15052152, "adsObject": {"genres": [], "styles": [], "query": {"type": "release"}}};
#             }
#         </script>
# <script>
#             window.ds = typeof window.ds == "function" ? window.ds : function(){
#                 (ds.q = ds.q || []).push(arguments);
#                 return ds;
#             };
#         </script>
# </link></meta></meta></meta></meta></head>
# <body class="">
# <div id="main_wrapper"> <div id="site_headers_super_wrap">
# <div id="site_header_wrap">
# <div aria-label="Discogs Header" id="site_header" role="banner">
# <a href="/" id="header_logo" title="Go to Discogs.com homepage">
# <img alt="" src="https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/images/discogs-white.png?5"/>
# </a>
# <form action="/search/" aria-label="Search Discogs" id="site_search" role="search">
# <input aria-label="Search artists, albums and more..." autocapitalize="off" autocorrect="off" class="autocomplete ac_type_a_m_r_13 ac_submit init" id="search_q" name="q" placeholder="Search artists, albums and more..." type="text" value=""/>
# <button aria-label="Search" class="submit button" id="do_site_search" name="" type="submit" value="">
# <i class="icon icon-search"></i>
# </button>
# <input class="advanced_search advanced_search_type" name="type" type="hidden" value="all"/>
# </form>
# <ul aria-label="Main Navigation" id="site_navigation" role="navigation">
# <li class="site_nav_group" data-id="explore" id="section_nav_explore">
# <a class="nav_group_control" href="/search/">Explore<i class="icon icon-caret-down"></i>
# </a>
# <div class="site_nav_submenu site_nav_tray" id="site_nav_tray_explore">
# <table>
# <tr>
# <td>
# <h4>Discover</h4>
# <ul>
# <li><a href="/search/?ev=em_rs">Explore All</a></li>
# <li><a href="/search/?type=release&amp;sort=hot%2Cdesc&amp;ev=em_tr">Trending Releases</a></li>
# <li><a href="/lists?ev=em_rl">List Explorer</a></li>
# <li><a href="/search/advanced?ev=em_as">Advanced Search</a></li>
# <li><a href="https://blog.discogs.com/en/tag/database-en/?utm_source=discogs&amp;utm_medium=referral&amp;utm_campaign=navigation_menu" target="_blank">Articles About Music</a></li>
# </ul>
# </td>
# <td>
# <h4>Contribute</h4>
# <ul>
# <li><a href="https://support.discogs.com/hc/articles/360004016474-Overview-of-Submission-Guidelines-for-Releases/?utm_source=discogs&amp;utm_medium=referral&amp;utm_campaign=navigation_menu" target="_blank">Submission Guidelines</a></li>
# <li><a href="/release/add?ev=em_sr" rel="nofollow">Submit a Release</a></li>
# <li><a href="https://support.discogs.com/hc/articles/360001567973/?utm_source=discogs&amp;utm_medium=referral&amp;utm_campaign=navigation_menu" target="_blank">How to Make a List</a>
# <li><a href="/leaderboard">Monthly Leaderboard</a></li>
# <li><a href="https://localization.discogs.com/?ev=em_bt" target="_blank">Help Translate Discogs</a></li>
# </li></ul>
# </td>
# <td>
# <div>
# <h4>Genres</h4>
# <ul>
# <li><a href="/genre/rock?ev=em_rp">Rock</a></li>
# <li><a href="/genre/electronic?ev=em_ep">Electronic</a></li>
# <li><a href="/genre/hip+hop?ev=em_pp">Hip Hop</a></li>
# <li><a href="/genre/folk%2C+world%2C+%26+country?ev=em_fwcp">Folk, World, &amp; Country</a></li>
# <li><a href="/genre/jazz?ev=em_jp">Jazz</a></li>
# </ul>
# </div>
# </td>
# <td>
# <div>
# <h4>Styles</h4>
# <ul>
# <li><a href="/style/house?ev=em_hp">House</a></li>
# <li><a href="/style/punk?ev=em_pup">Punk</a></li>
# <li><a href="/style/soul?ev=em_vp">Soul</a></li>
# <li><a href="https://blog.discogs.com/en/genres-and-styles-list/?utm_source=discogs&amp;utm_medium=referral&amp;utm_campaign=navigation_menu">Explore All Styles</a></li>
# <li><a href="https://blog.discogs.com/regional-music-styles/">Regional Style Map</a></li>
# </ul>
# </div>
# </td>
# </tr>
# </table>
# </div>
# </li>
# <li class="site_nav_group" data-id="marketplace" id="section_nav_marketplace">
# <a aria-label="Toggle Marketplace Menu" class="nav_group_control" href="/sell/list">
#                         Marketplace<i class="icon icon-caret-down"></i>
# </a>
# <div class="site_nav_submenu site_nav_tray" id="site_nav_tray_marketplace">
# <table>
# <tr>
# <td class="tray_formats">
# <h4>Format</h4>
# <ul>
# <li>
# <a href="/sell/list?format=Vinyl">
#                         Vinyl
#                     </a>
# </li>
# <li>
# <a href="/sell/list?format=CD">
#                         CD
#                     </a>
# </li>
# <li>
# <a href="/sell/list?format=Cassette">
#                         Cassette
#                     </a>
# </li>
# <li>
# <a href="/sell/list?format=DVD">
#                         DVD
#                     </a>
# </li>
# <li>
# <a href="/sell/list?format=Box+Set">
#                         Box Set
#                     </a>
# </li>
# </ul>
# </td>
# <td class="tray_genres">
# <h4>Genre</h4>
# <ul>
# <li>
# <a href="/sell/list?genre=Rock">
#                         Rock
#                     </a>
# </li>
# <li>
# <a href="/sell/list?genre=Electronic">
#                         Electronic
#                     </a>
# </li>
# <li>
# <a href="/sell/list?genre=Pop">
#                         Pop
#                     </a>
# </li>
# <li>
# <a href="/sell/list?genre=Funk+%2F+Soul">
#                         Funk / Soul
#                     </a>
# </li>
# <li>
# <a href="/sell/list?genre=Jazz">
#                         Jazz
#                     </a>
# </li>
# </ul>
# </td>
# <td class="tray_styles">
# <h4>Styles</h4>
# <ul>
# <li>
# <a href="/sell/list?style=Pop+Rock">
#                         Pop Rock
#                     </a>
# </li>
# <li>
# <a href="/sell/list?style=House">
#                         House
#                     </a>
# </li>
# <li>
# <a href="/sell/list?style=Disco">
#                         Disco
#                     </a>
# </li>
# <li>
# <a href="/sell/list?style=Synth-pop">
#                         Synth-pop
#                     </a>
# </li>
# <li>
# <a href="/sell/list?style=Soul">
#                         Soul
#                     </a>
# </li>
# </ul>
# </td>
# <td>
# <h4>
# <a href="/sell/list">
#                     Buy Music                </a>
# </h4>
# <ul>
# <li>
# <a href="/sell/list">
#                         All Items                    </a>
# </li>
# <li>
# <a href="/sell/mywants">
#                         Items I Want                    </a>
# </li>
# <li>
# <a href="/sell/purchases">
#                         Purchases                    </a>
# </li>
# <li>
# <a href="/sell/cart/">
#                         Cart                    </a>
# </li>
# <li>
# <a href="/record-store-day" target="_blank">
#                         Record Stores                    </a>
# </li>
# </ul>
# <td>
# <h4>Sell Music</h4>
# <ul>
# <li>
# <a href="/sell/">
#                         List Item For Sale                    </a>
# </li>
# <li>
# <a href="/sell/orders">
#                         Orders                    </a>
# </li>
# <li>
# <a href="/sell/manage">
#                         Inventory                    </a>
# </li>
# <li>
# <a href="/sell/billing">
#                         Billing                    </a>
# </li>
# </ul>
# </td>
# </td></tr>
# </table>
# </div>
# </li>
# <li class="site_nav_group" data-id="community" id="section_nav_community">
# <a aria-label="Toggle Community Menu" class="nav_group_control" href="/group/">
#                         Community<i class="icon icon-caret-down"></i>
# </a>
# <ul class="site_nav_submenu" id="site_nav_submenu_community">
# <li>
# <a href="https://www.discogs.com/digs">
#                                 Discogs Digs
#                             </a>
# </li>
# <li>
# <a href="/group/">
#                                 Groups                            </a>
# </li>
# <li>
# <a href="/forum/">
#                                 Forum                            </a>
# </li>
# <li>
# <a href="https://blog.discogs.com/en/">
#                                 Blog                            </a>
# </li>
# <li>
# <a href="/users/friends">
#                                 Friends                            </a>
# </li>
# <li>
# <a href="/help/doc/forums">
#                                 Community Guidelines                            </a>
# </li>
# <li>
# <a href="https://support.discogs.com/hc/articles/360004016474-Overview-of-Submission-Guidelines-for-Releases">
#                                 Database Guidelines                            </a>
# </li>
# <li>
# <a href="https://vinylhub.discogs.com?utm_source=discogs-top-nav&amp;utm_medium=referral" target="_blank">
#                                 Record Shops                            </a>
# </li>
# </ul>
# </li>
# </ul> <ul aria-label="Activity Menu" class="activity_menu_columns_4" id="activity_menu" role="navigation">
# <li>
# <a class="button-green button" href="/users/create">
#                             Register                        </a>
# </li>
# <li>
# <a class="nav_group_control" href="/login?return_to=%2Fsearch%2F%3Flimit%3D250%26sort%3Dhave%252Cdesc%26type%3Drelease%26page%3D1" id="log_in_link">
#                             Log In                        </a>
# </li>
# </ul> <a aria-label="Open Site Menu" class="" href="#mobile_site_navigation_toggle" id="mobile_site_navigation_toggle"><i class="icon icon-bars"></i></a>
# <ul id="mobile_site_navigation">
# <li id="activity_menu_placeholder"></li>
# <li id="site_navigation_placeholder"></li>
# </ul>
# </div> </div></div>
# <div class="ac_div" id="ac_search_q"></div>
# <div class="flash_messages">
# <noscript>
# <div class="alert-message alert-message-warning alert-message-top" data-alert-message-auto-close="false" data-alert-message-closable="false" id="alert-message-">
# <div class="alert-message-content float_fix">
# <i class="icon icon-exclamation-triangle alert-message-icon"></i>
# <span class="alert-message-text">
# <strong>Please enable Javascript to take full advantage of our site features.</strong>
# </span>
# </div>
# </div>
# </noscript>
# </div> <div class="aside_left aside_more_narrow with_tabs aside_off_canvas" id="page">
# <div class="" id="page_aside" role="complementary">
# <div class="hide_mobile">
# </div>
# <div>
# <h3 class="facets_header">Genre</h3>
# <ul class="no_vertical facets_nav">
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Rock">
# <small class="facet_count">4,979,860</small>
# <span class="facet_name">Rock</span>
# <span class="facet-bar" style="width: 33.08404007612998%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Electronic">
# <small class="facet_count">3,934,817</small>
# <span class="facet_name">Electronic</span>
# <span class="facet-bar" style="width: 26.141225520443857%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Pop">
# <small class="facet_count">2,989,911</small>
# <span class="facet_name">Pop</span>
# <span class="facet-bar" style="width: 19.86367796445319%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Folk%2C+World%2C+%26+Country">
# <small class="facet_count">1,844,476</small>
# <span class="facet_name">Folk, World, &amp; Country</span>
# <span class="facet-bar" style="width: 12.253902299152971%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Jazz">
# <small class="facet_count">1,223,449</small>
# <span class="facet_name">Jazz</span>
# <span class="facet-bar" style="width: 8.12806700330956%;"></span>
# </a>
# </li>
# </ul>
# <a class="more_facets_link" data-for="facets_genre_exact" href="#more_facets_genre_exact">
# <span class="more_facets_text">
#                         All<i class="icon icon-caret-down"></i>
# </span>
# </a>
# <div class="more_facets_dialog" data-title="Genre" id="facets_genre_exact" style="display: none;">
# <ul class="facets_nav">
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Rock">
# <small class="facet_count">4,979,860</small>
# <span class="facet_name">Rock</span>
# <span class="facet-bar" style="width: 33.08404007612998%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Electronic">
# <small class="facet_count">3,934,817</small>
# <span class="facet_name">Electronic</span>
# <span class="facet-bar" style="width: 26.141225520443857%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Pop">
# <small class="facet_count">2,989,911</small>
# <span class="facet_name">Pop</span>
# <span class="facet-bar" style="width: 19.86367796445319%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Folk%2C+World%2C+%26+Country">
# <small class="facet_count">1,844,476</small>
# <span class="facet_name">Folk, World, &amp; Country</span>
# <span class="facet-bar" style="width: 12.253902299152971%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Jazz">
# <small class="facet_count">1,223,449</small>
# <span class="facet_name">Jazz</span>
# <span class="facet-bar" style="width: 8.12806700330956%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Funk+%2F+Soul">
# <small class="facet_count">1,046,218</small>
# <span class="facet_name">Funk / Soul</span>
# <span class="facet-bar" style="width: 6.95062074844846%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Classical">
# <small class="facet_count">904,051</small>
# <span class="facet_name">Classical</span>
# <span class="facet-bar" style="width: 6.006124572752122%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Hip+Hop">
# <small class="facet_count">763,079</small>
# <span class="facet_name">Hip Hop</span>
# <span class="facet-bar" style="width: 5.069567461184288%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Latin">
# <small class="facet_count">616,655</small>
# <span class="facet_name">Latin</span>
# <span class="facet-bar" style="width: 4.096789615199209%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Stage+%26+Screen">
# <small class="facet_count">433,616</small>
# <span class="facet_name">Stage &amp; Screen</span>
# <span class="facet-bar" style="width: 2.8807575156030847%;"></span>
# </a>
# </li>
# </ul>
# <ul class="facets_nav">
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Reggae">
# <small class="facet_count">381,339</small>
# <span class="facet_name">Reggae</span>
# <span class="facet-bar" style="width: 2.533451695146315%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Blues">
# <small class="facet_count">325,785</small>
# <span class="facet_name">Blues</span>
# <span class="facet-bar" style="width: 2.1643749013430105%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Non-Music">
# <small class="facet_count">289,937</small>
# <span class="facet_name">Non-Music</span>
# <span class="facet-bar" style="width: 1.926216264624487%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Children%27s">
# <small class="facet_count">132,467</small>
# <span class="facet_name">Children's</span>
# <span class="facet-bar" style="width: 0.8800535631051295%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;genre_exact=Brass+%26+Military">
# <small class="facet_count">51,155</small>
# <span class="facet_name">Brass &amp; Military</span>
# <span class="facet-bar" style="width: 0.3398517368147757%;"></span>
# </a>
# </li>
# </ul>
# </div>
# <h3 class="facets_header">Style</h3>
# <ul class="no_vertical facets_nav">
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Pop+Rock">
# <small class="facet_count">767,139</small>
# <span class="facet_name">Pop Rock</span>
# <span class="facet-bar" style="width: 5.096540348516278%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=House">
# <small class="facet_count">593,264</small>
# <span class="facet_name">House</span>
# <span class="facet-bar" style="width: 3.9413899088980764%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Vocal">
# <small class="facet_count">502,401</small>
# <span class="facet_name">Vocal</span>
# <span class="facet-bar" style="width: 3.3377353616944605%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Experimental">
# <small class="facet_count">490,978</small>
# <span class="facet_name">Experimental</span>
# <span class="facet-bar" style="width: 3.261845880907926%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Punk">
# <small class="facet_count">466,040</small>
# <span class="facet_name">Punk</span>
# <span class="facet-bar" style="width: 3.096168574433742%;"></span>
# </a>
# </li>
# </ul>
# <a class="more_facets_link" data-for="facets_style_exact" href="#more_facets_style_exact">
# <span class="more_facets_text">
#                         All<i class="icon icon-caret-down"></i>
# </span>
# </a>
# <div class="more_facets_dialog" data-title="Style" id="facets_style_exact" style="display: none;">
# <ul class="facets_nav">
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Pop+Rock">
# <small class="facet_count">767,139</small>
# <span class="facet_name">Pop Rock</span>
# <span class="facet-bar" style="width: 5.096540348516278%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=House">
# <small class="facet_count">593,264</small>
# <span class="facet_name">House</span>
# <span class="facet-bar" style="width: 3.9413899088980764%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Vocal">
# <small class="facet_count">502,401</small>
# <span class="facet_name">Vocal</span>
# <span class="facet-bar" style="width: 3.3377353616944605%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Experimental">
# <small class="facet_count">490,978</small>
# <span class="facet_name">Experimental</span>
# <span class="facet-bar" style="width: 3.261845880907926%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Punk">
# <small class="facet_count">466,040</small>
# <span class="facet_name">Punk</span>
# <span class="facet-bar" style="width: 3.096168574433742%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Synth-pop">
# <small class="facet_count">442,683</small>
# <span class="facet_name">Synth-pop</span>
# <span class="facet-bar" style="width: 2.9409947494550943%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Alternative+Rock">
# <small class="facet_count">423,013</small>
# <span class="facet_name">Alternative Rock</span>
# <span class="facet-bar" style="width: 2.810315760829415%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Techno">
# <small class="facet_count">389,565</small>
# <span class="facet_name">Techno</span>
# <span class="facet-bar" style="width: 2.588101688050984%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Disco">
# <small class="facet_count">375,473</small>
# <span class="facet_name">Disco</span>
# <span class="facet-bar" style="width: 2.4944805234494045%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Soul">
# <small class="facet_count">366,205</small>
# <span class="facet_name">Soul</span>
# <span class="facet-bar" style="width: 2.4329079323674114%;"></span>
# </a>
# </li>
# </ul>
# <ul class="facets_nav">
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Indie+Rock">
# <small class="facet_count">357,976</small>
# <span class="facet_name">Indie Rock</span>
# <span class="facet-bar" style="width: 2.3782380087578177%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Hardcore">
# <small class="facet_count">337,763</small>
# <span class="facet_name">Hardcore</span>
# <span class="facet-bar" style="width: 2.243951562540692%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Ambient">
# <small class="facet_count">336,178</small>
# <span class="facet_name">Ambient</span>
# <span class="facet-bar" style="width: 2.233421506771922%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Folk">
# <small class="facet_count">315,637</small>
# <span class="facet_name">Folk</span>
# <span class="facet-bar" style="width: 2.0969559701496503%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Hard+Rock">
# <small class="facet_count">305,639</small>
# <span class="facet_name">Hard Rock</span>
# <span class="facet-bar" style="width: 2.030533574202546%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Ballad">
# <small class="facet_count">291,182</small>
# <span class="facet_name">Ballad</span>
# <span class="facet-bar" style="width: 1.93448750716841%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Country">
# <small class="facet_count">287,392</small>
# <span class="facet_name">Country</span>
# <span class="facet-bar" style="width: 1.9093083832796798%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Electro">
# <small class="facet_count">285,989</small>
# <span class="facet_name">Electro</span>
# <span class="facet-bar" style="width: 1.899987456943034%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Rock+%26+Roll">
# <small class="facet_count">267,838</small>
# <span class="facet_name">Rock &amp; Roll</span>
# <span class="facet-bar" style="width: 1.7794000485777715%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Chanson">
# <small class="facet_count">251,215</small>
# <span class="facet_name">Chanson</span>
# <span class="facet-bar" style="width: 1.6689640125877017%;"></span>
# </a>
# </li>
# </ul>
# <ul class="facets_nav">
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Trance">
# <small class="facet_count">245,683</small>
# <span class="facet_name">Trance</span>
# <span class="facet-bar" style="width: 1.632211792705787%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Heavy+Metal">
# <small class="facet_count">241,307</small>
# <span class="facet_name">Heavy Metal</span>
# <span class="facet-bar" style="width: 1.603139537788351%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Psychedelic+Rock">
# <small class="facet_count">230,898</small>
# <span class="facet_name">Psychedelic Rock</span>
# <span class="facet-bar" style="width: 1.5339866352665055%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Classic+Rock">
# <small class="facet_count">221,339</small>
# <span class="facet_name">Classic Rock</span>
# <span class="facet-bar" style="width: 1.4704807658067764%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Folk+Rock">
# <small class="facet_count">220,851</small>
# <span class="facet_name">Folk Rock</span>
# <span class="facet-bar" style="width: 1.4672387044722908%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Downtempo">
# <small class="facet_count">216,836</small>
# <span class="facet_name">Downtempo</span>
# <span class="facet-bar" style="width: 1.4405647777141766%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Soundtrack">
# <small class="facet_count">207,693</small>
# <span class="facet_name">Soundtrack</span>
# <span class="facet-bar" style="width: 1.3798226326707304%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Noise">
# <small class="facet_count">206,546</small>
# <span class="facet_name">Noise</span>
# <span class="facet-bar" style="width: 1.3722024598210276%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Prog+Rock">
# <small class="facet_count">204,867</small>
# <span class="facet_name">Prog Rock</span>
# <span class="facet-bar" style="width: 1.3610479086312708%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Romantic">
# <small class="facet_count">201,388</small>
# <span class="facet_name">Romantic</span>
# <span class="facet-bar" style="width: 1.3379349344864442%;"></span>
# </a>
# </li>
# </ul>
# <hr/>
# <ul class="facets_nav">
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Schlager">
# <small class="facet_count">196,472</small>
# <span class="facet_name">Schlager</span>
# <span class="facet-bar" style="width: 1.3052751526824868%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Funk">
# <small class="facet_count">196,351</small>
# <span class="facet_name">Funk</span>
# <span class="facet-bar" style="width: 1.304471280917174%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Easy+Listening">
# <small class="facet_count">182,714</small>
# <span class="facet_name">Easy Listening</span>
# <span class="facet-bar" style="width: 1.2138729398959034%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Tech+House">
# <small class="facet_count">172,820</small>
# <span class="facet_name">Tech House</span>
# <span class="facet-bar" style="width: 1.1481414750528696%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Blues+Rock">
# <small class="facet_count">170,201</small>
# <span class="facet_name">Blues Rock</span>
# <span class="facet-bar" style="width: 1.130741969653243%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Black+Metal">
# <small class="facet_count">168,232</small>
# <span class="facet_name">Black Metal</span>
# <span class="facet-bar" style="width: 1.1176607836540584%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=New+Wave">
# <small class="facet_count">167,724</small>
# <span class="facet_name">New Wave</span>
# <span class="facet-bar" style="width: 1.1142858509534053%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Rhythm+%26+Blues">
# <small class="facet_count">160,859</small>
# <span class="facet_name">Rhythm &amp; Blues</span>
# <span class="facet-bar" style="width: 1.0686777545164305%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Deep+House">
# <small class="facet_count">159,417</small>
# <span class="facet_name">Deep House</span>
# <span class="facet-bar" style="width: 1.059097729015758%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Industrial">
# <small class="facet_count">158,035</small>
# <span class="facet_name">Industrial</span>
# <span class="facet-bar" style="width: 1.0499163176135877%;"></span>
# </a>
# </li>
# </ul>
# <ul class="facets_nav">
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Euro+House">
# <small class="facet_count">152,094</small>
# <span class="facet_name">Euro House</span>
# <span class="facet-bar" style="width: 1.010446878293549%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Progressive+House">
# <small class="facet_count">148,951</small>
# <span class="facet_name">Progressive House</span>
# <span class="facet-bar" style="width: 0.9895661431003354%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Death+Metal">
# <small class="facet_count">147,247</small>
# <span class="facet_name">Death Metal</span>
# <span class="facet-bar" style="width: 0.9782455027028693%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Drum+n+Bass">
# <small class="facet_count">145,898</small>
# <span class="facet_name">Drum n Bass</span>
# <span class="facet-bar" style="width: 0.9692833290548754%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Classical">
# <small class="facet_count">144,429</small>
# <span class="facet_name">Classical</span>
# <span class="facet-bar" style="width: 0.9595239272098768%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Soft+Rock">
# <small class="facet_count">139,628</small>
# <span class="facet_name">Soft Rock</span>
# <span class="facet-bar" style="width: 0.9276281557613822%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Abstract">
# <small class="facet_count">134,425</small>
# <span class="facet_name">Abstract</span>
# <span class="facet-bar" style="width: 0.8930616698529219%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Garage+Rock">
# <small class="facet_count">129,451</small>
# <span class="facet_name">Garage Rock</span>
# <span class="facet-bar" style="width: 0.8600165610870791%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Minimal">
# <small class="facet_count">121,550</small>
# <span class="facet_name">Minimal</span>
# <span class="facet-bar" style="width: 0.807525727882631%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Europop">
# <small class="facet_count">119,556</small>
# <span class="facet_name">Europop</span>
# <span class="facet-bar" style="width: 0.794278452675737%;"></span>
# </a>
# </li>
# </ul>
# <ul class="facets_nav">
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Acoustic">
# <small class="facet_count">108,894</small>
# <span class="facet_name">Acoustic</span>
# <span class="facet-bar" style="width: 0.7234447273718735%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Thrash">
# <small class="facet_count">108,759</small>
# <span class="facet_name">Thrash</span>
# <span class="facet-bar" style="width: 0.7225478456502432%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Gospel">
# <small class="facet_count">108,134</small>
# <span class="facet_name">Gospel</span>
# <span class="facet-bar" style="width: 0.7183956154575106%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Swing">
# <small class="facet_count">100,478</small>
# <span class="facet_name">Swing</span>
# <span class="facet-bar" style="width: 0.6675324564886137%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=RnB%2FSwing">
# <small class="facet_count">99,855</small>
# <span class="facet_name">RnB/Swing</span>
# <span class="facet-bar" style="width: 0.6633935134324979%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Big+Band">
# <small class="facet_count">99,157</small>
# <span class="facet_name">Big Band</span>
# <span class="facet-bar" style="width: 0.6587563027532541%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Baroque">
# <small class="facet_count">97,507</small>
# <span class="facet_name">Baroque</span>
# <span class="facet-bar" style="width: 0.6477944150444402%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Country+Rock">
# <small class="facet_count">95,799</small>
# <span class="facet_name">Country Rock</span>
# <span class="facet-bar" style="width: 0.6364472003737406%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Dub">
# <small class="facet_count">94,262</small>
# <span class="facet_name">Dub</span>
# <span class="facet-bar" style="width: 0.6262360358837726%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Modern">
# <small class="facet_count">93,407</small>
# <span class="facet_name">Modern</span>
# <span class="facet-bar" style="width: 0.6205557849801144%;"></span>
# </a>
# </li>
# </ul>
# <hr/>
# <ul class="facets_nav">
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Breakbeat">
# <small class="facet_count">91,308</small>
# <span class="facet_name">Breakbeat</span>
# <span class="facet-bar" style="width: 0.6066109351008414%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Contemporary+Jazz">
# <small class="facet_count">90,373</small>
# <span class="facet_name">Contemporary Jazz</span>
# <span class="facet-bar" style="width: 0.6003991987325135%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Progressive+Trance">
# <small class="facet_count">86,139</small>
# <span class="facet_name">Progressive Trance</span>
# <span class="facet-bar" style="width: 0.5722703305148659%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Drone">
# <small class="facet_count">84,637</small>
# <span class="facet_name">Drone</span>
# <span class="facet-bar" style="width: 0.562291690915691%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Dancehall">
# <small class="facet_count">83,364</small>
# <span class="facet_name">Dancehall</span>
# <span class="facet-bar" style="width: 0.5538344284591333%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Indie+Pop">
# <small class="facet_count">77,324</small>
# <span class="facet_name">Indie Pop</span>
# <span class="facet-bar" style="width: 0.5137072758765656%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Breaks">
# <small class="facet_count">76,765</small>
# <span class="facet_name">Breaks</span>
# <span class="facet-bar" style="width: 0.5099935211921857%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Opera">
# <small class="facet_count">76,684</small>
# <span class="facet_name">Opera</span>
# <span class="facet-bar" style="width: 0.5094553921592075%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=IDM">
# <small class="facet_count">75,570</small>
# <span class="facet_name">IDM</span>
# <span class="facet-bar" style="width: 0.5020544570636809%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Contemporary">
# <small class="facet_count">75,322</small>
# <span class="facet_name">Contemporary</span>
# <span class="facet-bar" style="width: 0.5004068521232048%;"></span>
# </a>
# </li>
# </ul>
# <ul class="facets_nav">
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Reggae">
# <small class="facet_count">72,888</small>
# <span class="facet_name">Reggae</span>
# <span class="facet-bar" style="width: 0.484236406860627%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Art+Rock">
# <small class="facet_count">70,300</small>
# <span class="facet_name">Art Rock</span>
# <span class="facet-bar" style="width: 0.46704285207855994%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=African">
# <small class="facet_count">69,444</small>
# <span class="facet_name">African</span>
# <span class="facet-bar" style="width: 0.4613559576065934%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Fusion">
# <small class="facet_count">68,818</small>
# <span class="facet_name">Fusion</span>
# <span class="facet-bar" style="width: 0.45719708384555247%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Avantgarde">
# <small class="facet_count">65,564</small>
# <span class="facet_name">Avantgarde</span>
# <span class="facet-bar" style="width: 0.4355789125701096%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Hard+Trance">
# <small class="facet_count">64,929</small>
# <span class="facet_name">Hard Trance</span>
# <span class="facet-bar" style="width: 0.4313602466942933%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Gangsta">
# <small class="facet_count">64,559</small>
# <span class="facet_name">Gangsta</span>
# <span class="facet-bar" style="width: 0.4289021264201956%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Dark+Ambient">
# <small class="facet_count">64,508</small>
# <span class="facet_name">Dark Ambient</span>
# <span class="facet-bar" style="width: 0.4285633044364686%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Doom+Metal">
# <small class="facet_count">63,616</small>
# <span class="facet_name">Doom Metal</span>
# <span class="facet-bar" style="width: 0.42263724150540066%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Pop+Rap">
# <small class="facet_count">63,010</small>
# <span class="facet_name">Pop Rap</span>
# <span class="facet-bar" style="width: 0.4186112391105272%;"></span>
# </a>
# </li>
# </ul>
# <ul class="facets_nav">
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Electro+House">
# <small class="facet_count">62,167</small>
# <span class="facet_name">Electro House</span>
# <span class="facet-bar" style="width: 0.4130107110265695%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Rockabilly">
# <small class="facet_count">61,797</small>
# <span class="facet_name">Rockabilly</span>
# <span class="facet-bar" style="width: 0.4105525907524718%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Religious">
# <small class="facet_count">61,689</small>
# <span class="facet_name">Religious</span>
# <span class="facet-bar" style="width: 0.4098350853751676%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Beat">
# <small class="facet_count">61,283</small>
# <span class="facet_name">Beat</span>
# <span class="facet-bar" style="width: 0.4071377966419686%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Roots+Reggae">
# <small class="facet_count">60,671</small>
# <span class="facet_name">Roots Reggae</span>
# <span class="facet-bar" style="width: 0.40307193283724474%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Jazz-Funk">
# <small class="facet_count">60,265</small>
# <span class="facet_name">Jazz-Funk</span>
# <span class="facet-bar" style="width: 0.4003746441040458%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Post-Punk">
# <small class="facet_count">59,916</small>
# <span class="facet_name">Post-Punk</span>
# <span class="facet-bar" style="width: 0.3980560387644239%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Lo-Fi">
# <small class="facet_count">57,335</small>
# <span class="facet_name">Lo-Fi</span>
# <span class="facet-bar" style="width: 0.3809089889605154%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Acid">
# <small class="facet_count">56,526</small>
# <span class="facet_name">Acid</span>
# <span class="facet-bar" style="width: 0.3755343421990424%;"></span>
# </a>
# </li>
# <li>
# <a href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=1&amp;style_exact=Comedy">
# <small class="facet_count">56,001</small>
# <span class="facet_name">Comedy</span>
# ...
# <h5>
# <span title="Van Halen">
# <a href="/artist/94066-Van-Halen">Van Halen</a></span></h5>
# <div class="card_actions skittles">
# <span aria-label="0 in Collection" class="skittle skittle_collection needs_delegated_tooltip" data-title="0 in Collection" style="display: none;" title="0 in Collection"><i class="icon icon-collection"></i><span class="count">0</span>
# </span> <span aria-label="0 in Wantlist" class="skittle skittle_wantlist needs_delegated_tooltip" data-title="0 in Wantlist" style="display: none;" title="0 in Wantlist"><i class="icon icon-wantlist"></i><span class="count">0</span>
# </span> <a aria-label="0 in Inventory" class="skittle skittle_inventory needs_delegated_tooltip" data-title="0 in Inventory" href="/sell/release/413315?seller=Anonymous" style="display: none;" title="0 in Inventory"><i class="icon icon-store"></i><span class="count">0</span>
# </a>
# </div>
# </div>
# <div class="card card_large float_fix shortcut_navigable" data-id="r413315" data-master-id="96689" data-object-id="413315" data-object-type="release">
# <a class="thumbnail_link thumbnail_size_large thumbnail_orientation_portrait thumbnail-lazyload" href="/release/413315-George-Michael-Faith">
# <span class="thumbnail_border"></span>
# <span class="thumbnail_center">
# <img alt="Faith" data-src="https://i.discogs.com/8_fFA-avO43FHgc3mnYaYGI92b97K7KKYxP9WjsI6wM/rs:fill/g:sm/q:40/h:300/w:300/czM6Ly9kaXNjb2dz/LWRhdGFiYXNlLWlt/YWdlcy9SLTQxMzMx/NS0xNTE0NDY2NjUx/LTQ0ODQuanBlZw.jpeg" src="..."/>
# </span>
# </a>
# <h4><a class="search_result_title" data-followable="true" href="/release/413315-George-Michael-Faith" title="Faith">Faith</a></h4>
# <h5>
# <span title="George Michael">
# <a href="/artist/32990-George-Michael">George Michael</a></span></h5>
# <div class="card_actions skittles">
# <span aria-label="0 in Collection" class="skittle skittle_collection needs_delegated_tooltip" data-title="0 in Collection" style="display: none;" title="0 in Collection"><i class="icon icon-collection"></i><span class="count">0</span>
# </span> <span aria-label="0 in Wantlist" class="skittle skittle_wantlist needs_delegated_tooltip" data-title="0 in Wantlist" style="display: none;" title="0 in Wantlist"><i class="icon icon-wantlist"></i><span class="count">0</span>
# </span> <a aria-label="0 in Inventory" class="skittle skittle_inventory needs_delegated_tooltip" data-title="0 in Inventory" href="/sell/release/413315?seller=Anonymous" style="display: none;" title="0 in Inventory"><i class="icon icon-store"></i><span class="count">0</span>
# </a>
# </div>
# </div>
# </div>
# <div class="pagination bottom">
# <form action="/search/" data-section="general" method="get">
# <strong class="pagination_total">
#         1 – 250 of 15,052,152    </strong>
# <div class="responsive_wrap">
# <ul class="pagination_page_links">
# <li>
# <span><i class="icon icon-chevron-left"></i>Prev</span>
# </li>
# <li>
# <a class="pagination_next" href="/search/?limit=250&amp;sort=have%2Cdesc&amp;type=release&amp;page=2">Next<i class="icon icon-chevron-right"></i></a>
# </li>
# </ul>
# </div>
# <div class="pagination_controls multiple_filters">
# <label class="hide_mobile" for="limit_bottom">Show</label>
# <select class="hide_mobile" id="limit_bottom" name="limit">
# <option value="25">25</option><option value="50">50</option><option value="100">100</option><option selected="selected" value="250">250</option>
# </select>
# <noscript><button type="submit">Refresh</button></noscript>
# </div>
# <input name="sort" type="hidden" value="have,desc"/>
# <input name="type" type="hidden" value="release"/>
# </form>
# </div>
# </div>
# </div>
# </div> <div class="sticky_footer">
# <button id="move"><i class="icon icon-close"></i></button>
# <div class="ad_container ad_bottom" id="ad_bottom"></div>
# </div>
# <div id="push_footer"></div>
# </div>
# <div id="site_footer_wrap">
# <div aria-label="Footer Navigation" id="site_footer" role="navigation"><div class="banner_ad pub_300x250 pub_300x250m pub_728x90 text-ad textAd text_ad text_ads text-ads text-ad-links">
# </div>
# <ul id="site_footer_list">
# <li>
# <h5>Discogs</h5>
# <ul>
# <li>
# <a href="https://www.discogs.com/company">
#                             About Us</a>
# </li>
# <li>
# <a href="https://blog.discogs.com/en/">
#                             Blog</a>
# </li>
# <li>
# <a href="/app">
#                             App</a>
# </li>
# <li>
# <a href="https://www.discogs.com/company/careers">
#                             Careers</a>
# </li>
# <li>
# <a href="/developers">
#                             API</a>
# </li>
# <li>
# <a href="https://blog.discogs.com/en/tag/engineering-en/">
#                             Change Log</a>
# </li>
# </ul>
# </li>
# <li>
# <h5>Help Is Here</h5>
# <ul>
# <li>
# <a href="https://support.discogs.com">
#                             Help &amp; Support</a>
# </li>
# <li>
# <a href="/forum/">
#                             Forum</a>
# </li>
# <li>
# <a class="show_keyboard_shortcuts" href="#show_keyboard_shortcuts">
#                             Keyboard Shortcuts                        </a>
# </li>
# <li>
# <a href="https://support.discogs.com/hc/articles/360004016474-Overview-of-Submission-Guidelines-for-Releases">Database Guidelines</a>
# </li>
# <li>
# <a href="/shipping">Discogs Shipping</a>
# </li>
# </ul>
# </li>
# <li>
# <h5>Join In</h5>
# <ul>
# <li>
# <a href="/getstarted/">
#                             Get Started</a>
# </li>
# <li>
# <a href="/users/create">
#                                 Sign Up</a>
# </li>
# <li>
# <a href="https://www.discogs.com/digs">
#                             Discogs Digs
#                         </a>
# </li>
# <li>
# <a href="/help/doc/contributing">
#                             Contribute</a>
# </li>
# <li>
# <a href="/release/add">
#                             Add Release</a>
# </li>
# <li>
# <a href="/stats/contributors">
#                             Contributor List</a>
# </li>
# <li>
# <a href="https://support.discogs.com/hc/articles/360001585814-How-Can-I-Help-Translate-Discogs-">
#                             Help Translate</a>
# </li>
# <li>
# <a href="/record-store-day">
#                             Record Stores                        </a>
# </li>
# <li>
# <a href="/cdn-cgi/l/email-protection#dba8bab7bea89bbfb2a8b8b4bca8f5b8b4b6">
#                             Advertise With Us</a>
# </li>
# </ul>
# </li>
# <li>
# <h5>Follow Us</h5>
# <ul>
# <li>
# <a href="https://www.facebook.com/discogs">
# <i class="icon icon-facebook-square"></i>Facebook
#                         </a>
# </li>
# <li>
# <a href="https://twitter.com/discogs">
# <i class="icon icon-twitter"></i>Twitter
#                         </a>
# </li>
# <li>
# <a href="https://youtube.com/discogs">
# <i class="icon icon-youtube"></i>YouTube
#                         </a>
# </li>
# <li>
# <a href="https://www.instagram.com/discogs/">
# <i class="icon icon-instagram"></i>Instagram
#                         </a>
# </li>
# <li>
# <a href="http://www.mixcloud.com/discogs/">
# <i class="icon icon-mixcloud"></i>Mixcloud
#                         </a>
# </li>
# <li>
# <a href="https://soundcloud.com/discogs">
# <i class="icon icon-soundcloud"></i>Soundcloud
#                         </a>
# </li>
# <li>
# <a href="https://www.pinterest.com/officialdiscogs/">
# <i class="icon icon-pinterest"></i>Pinterest
#                         </a>
# </li>
# </ul>
# </li> </ul> </div> <div id="site_footer_legal">
# <div><img alt="" src="https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/images/discogs-white.png?5"/>
# <span id="copyright">
#                 © 2022 Discogs®
#             </span>
# <button class="ot-sdk-show-settings" id="ot-sdk-btn"> Cookie Settings</button>
# <a href="/help/doc/cookie-policy" id="cookie_link">Cookie Policy</a>
# <a href="/help/doc/terms-of-service" id="terms_link">Terms of Service</a>
# <a href="/help/doc/privacy-policy" id="privacy_link">Privacy Policy</a>
# <a href="https://support.discogs.com/hc/articles/360039846494-California-Privacy-Notice">California Privacy Notice</a>
# <a href="https://support.discogs.com/hc/en-us/articles/360017786278-Accessibility-Statement" target="_blank">Accessibility Statement</a>
# <span id="language_container">
# <a data-code="en" data-name="English" href="#select-language" id="i18n_link">
# <i class="icon icon-globe"></i>
#                     English
#                     <i class="icon icon-caret-down"></i>
# </a>
# <select id="i18n_select"> <option class="language" id="language_de_field" name="language_code" value="de"> Deutsch </option>
# <option class="language" id="language_en_field" name="language_code" selected="" value="en"> English </option>
# <option class="language" id="language_es_field" name="language_code" value="es"> Español </option>
# <option class="language" id="language_fr_field" name="language_code" value="fr"> Français </option>
# <option class="language" id="language_it_field" name="language_code" value="it"> Italiano </option>
# <option class="language" id="language_ja_field" name="language_code" value="ja"> 日本語 </option>
# <option class="language" id="language_ko_field" name="language_code" value="ko"> 한국어 </option>
# <option class="language" id="language_pt_BR_field" name="language_code" value="pt_BR"> Português (Brasil) </option>
# <option class="language" id="language_ru_field" name="language_code" value="ru"> Русский </option>
# </select>
# </span><a id="footer_menu_link">
# <i class="icon icon-chevron-down"></i>
# <i class="icon icon-chevron-up"></i>
# </a>
# </div>
# </div>
# </div>
# <div id="act"></div>
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script type="text/javascript">
# !function(){"use strict";function a(a){return"function"==typeof a||"object"==typeof a&&null!==a}function b(a){return"function"==typeof a}function c(a){return"object"==typeof a&&null!==a}function g(){}function n(){return function(){process.nextTick(s)}}function o(){var a=0,b=new l(s),c=document.createTextNode("");return b.observe(c,{characterData:!0}),function(){c.data=a=++a%2}}function p(){var a=new MessageChannel;return a.port1.onmessage=s,function(){a.port2.postMessage(0)}}function q(){return function(){setTimeout(s,1)}}function s(){for(var a=0;i>a;a+=2){var b=r[a],c=r[a+1];b(c),r[a]=void 0,r[a+1]=void 0}i=0}function u(){}function z(){return new TypeError("You cannot resolve a promise with itself")}function A(){return new TypeError("A promises callback cannot return that same promise.")}function B(a){try{return a.then}catch(b){return y.error=b,y}}function C(a,b,c,d){try{a.call(b,c,d)}catch(e){return e}}function D(a,b,c){j(function(a){var d=!1,e=C(c,b,function(c){d||(d=!0,b!==c?G(a,c):I(a,c))},function(b){d||(d=!0,J(a,b))},"Settle: "+(a._label||" unknown promise"));!d&&e&&(d=!0,J(a,e))},a)}function E(a,b){b._state===w?I(a,b._result):a._state===x?J(a,b._result):K(b,void 0,function(b){G(a,b)},function(b){J(a,b)})}function F(a,c){if(c.constructor===a.constructor)E(a,c);else{var d=B(c);d===y?J(a,y.error):void 0===d?I(a,c):b(d)?D(a,c,d):I(a,c)}}function G(b,c){b===c?J(b,z()):a(c)?F(b,c):I(b,c)}function H(a){a._onerror&&a._onerror(a._result),L(a)}function I(a,b){a._state===v&&(a._result=b,a._state=w,0===a._subscribers.length||j(L,a))}function J(a,b){a._state===v&&(a._state=x,a._result=b,j(H,a))}function K(a,b,c,d){var e=a._subscribers,f=e.length;a._onerror=null,e[f]=b,e[f+w]=c,e[f+x]=d,0===f&&a._state&&j(L,a)}function L(a){var b=a._subscribers,c=a._state;if(0!==b.length){for(var d,e,f=a._result,g=0;g<b.length;g+=3)d=b[g],e=b[g+c],d?P(c,d,e,f):e(f);a._subscribers.length=0}}function M(){this.error=null}function O(a,b){try{return a(b)}catch(c){return N.error=c,N}}function P(a,c,d,e){var g,h,i,j,f=b(d);if(f){if(g=O(d,e),g===N?(j=!0,h=g.error,g=null):i=!0,c===g)return J(c,A()),void 0}else g=e,i=!0;c._state!==v||(f&&i?G(c,g):j?J(c,h):a===w?I(c,g):a===x&&J(c,g))}function Q(a,b){try{b(function(b){G(a,b)},function(b){J(a,b)})}catch(c){J(a,c)}}function S(a,b,c,d){this._instanceConstructor=a,this.promise=new a(u,d),this._abortOnReject=c,this._validateInput(b)?(this._input=b,this.length=b.length,this._remaining=b.length,this._init(),0===this.length?I(this.promise,this._result):(this.length=this.length||0,this._enumerate(),0===this._remaining&&I(this.promise,this._result))):J(this.promise,this._validationError())}function Z(){throw new TypeError("You must pass a resolver function as the first argument to the promise constructor")}function $(){throw new TypeError("Failed to construct 'Promise': Please use the 'new' operator, this object constructor cannot be called as a function.")}function ab(a,c){this._id=Y++,this._label=c,this._state=void 0,this._result=void 0,this._subscribers=[],u!==a&&(b(a)||Z(),this instanceof ab||$(),Q(this,a))}var d;d=Array.isArray?Array.isArray:function(a){return"[object Array]"===Object.prototype.toString.call(a)};var e=d;Date.now||function(){return(new Date).getTime()},Object.create||function(a){if(arguments.length>1)throw new Error("Second argument not supported");if("object"!=typeof a)throw new TypeError("Argument must be an object");return g.prototype=a,new g};var t,i=0,j=function(a,b){r[i]=a,r[i+1]=b,i+=2,2===i&&t()},k="undefined"!=typeof window?window:{},l=k.MutationObserver||k.WebKitMutationObserver,m="undefined"!=typeof Uint8ClampedArray&&"undefined"!=typeof importScripts&&"undefined"!=typeof MessageChannel,r=new Array(1e3);t="undefined"!=typeof process&&"[object process]"==={}.toString.call(process)?n():l?o():m?p():q();var v=void 0,w=1,x=2,y=new M,N=new M;S.prototype._validateInput=function(a){return e(a)},S.prototype._validationError=function(){return new Error("Array Methods must be provided an Array")},S.p ...
#
# ES6Promise.polyfill();
# </script>
# <!--[if lte IE 9]>    <script src="https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/dst/javascripts/vendor.js"></script>
#     <script src="https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/dst/javascripts/discogs.js"></script>
#     <script src="https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/dst/javascripts/sections/search.js"></script>
# <script>ds.require('app')</script>
# <script>ds.require('googleTagServices');</script><![endif]-->
# <!--[if gt IE 9]><!-->
# <script>
# (function(scripts){
#
#     var i = -1, l = scripts.length - 1;
#     var startTime = new Date().getTime();
#     var _scripts  = [];
#     var loads     = [];
#     var j;
#
#     var head = document.head || document.getElementsByTagName('head')[0];
#
#     function log(){
#         window.console && console.log && console.log.apply(console, arguments);
#     }
#
#     function makeScript(src){
#         var element  = document.createElement('script');
#         var isVendor = !!src.match(/javascripts\/(vendor|react-bundle)/);
#         var isSync   = !!(src.match('javascripts/define.js') || src.match('discogs.js') || src.match('moment-lib.js'));
#         var isAsync  = !(isVendor || isSync);
#         var load     = new Promise(function(resolve){
#             element.onload = function(){ resolve(src); };
#             element.src = src;
#             element.setAttribute('defer', 'defer');
#             if (isAsync) {
#                 element.setAttribute('async', 'async');
#             }
#         });
#         _scripts.push({ element: element, load: load, isAsync: isAsync });
#     }
#
#     for (j = 0; j <= l; j++) {
#         makeScript(scripts[j]);
#     }
#
#     for (j = 0; j <= l; j++) {
#         loads.push(_scripts[j].load);
#     }
#
#     Promise.all(loads).then(function(urls){
#                 var app = ds.require('app');
#             });
#
#     function loadNext(){
#         i++;
#         var script = _scripts[i];
#         if (script) {
#             head.appendChild(script.element);
#             if (script.isAsync) {
#                 loadNext();
#             } else {
#                 script.load.then(loadNext);
#             }
#         }
#     }
#
#     loadNext();
#
# })(["https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/dst/javascripts/vendor.js", "https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/dst/javascripts/discogs.js", "https://s.discogs.com/53735943f116d10c83937e2c850ad367a600ecc9/dst/javascripts/sections/search.js"]);
# </script>
# <!--<![endif]-->
# <script>
# ds(function(require){
#     require("search");
#     require("pagination");
# });
#
# </script>
# </body>
# </html>

# %% [markdown]
# Locate:
# - song name
# - artist

# %% [markdown]
# #### Song names

# %%
soup_1.select("div:nth-child(1)>h4>a")[0].get_text()
# Out:
# 'Random Access Memories'

# %%
# This is just for one page right now
song_names = []
for div in soup_1.find_all("div", {"class": "card card_large float_fix shortcut_navigable"}):
    for elem in div.find_all("h4"):
        song_names.append(elem.get_text().replace("\n",""))
song_names
# Out:
# ['Random Access Memories',
#  'Good Kid, M.A.A.d City',
#  'Thriller',
#  'The Dark Side Of The Moon',
#  'Rumours',
#  'The Dark Side Of The Moon',
#  'Lazaretto',
#  'Purple Rain',
#  'Nevermind',
#  'Harvest',
#  'The Rise And Fall Of Ziggy Stardust And The Spiders From Mars',
#  'Hotel California',
#  'Born In The U.S.A.',
#  'AM',
#  'Thriller',
#  'Brothers In Arms',
#  'Déjà Vu',
#  'The Cars',
#  'My Beautiful Dark Twisted Fantasy',
#  'Lost In The Dream',
#  'Breakfast In America',
#  'Carrie & Lowell',
#  'Bridge Over Troubled Water',
#  'Wish You Were Here',
#  'The Chronic',
#  'Fleet Foxes',
#  "(What's The Story) Morning Glory?",
#  'The Stranger',
#  'Bad',
#  'Wish You Were Here',
#  'The Dark Side Of The Moon',
#  'For Emma, Forever Ago',
#  'Let It Be',
#  'Lateralus',
#  'Untitled',
#  'Tapestry',
#  'Discovery',
#  'Johnny Cash At San Quentin',
#  'Grease (The Original Soundtrack From The Motion Picture)',
#  'Mezzanine',
#  'In Rainbows',
#  'Back To Black',
#  'Frampton Comes Alive!',
#  'Enter The Wu-Tang (36 Chambers)',
#  'Madvillainy',
#  'The Wall',
#  '4',
#  'Magical Mystery Tour',
#  'In The Aeroplane Over The Sea',
#  'Glass Houses',
#  'Led Zeppelin III',
#  'Hunky Dory',
#  "Simon And Garfunkel's Greatest Hits",
#  'Sports',
#  'Star Wars',
#  'Dirt',
#  'Off The Wall',
#  'In The Court Of The Crimson King',
#  'Rumours',
#  'Pearl',
#  'Escape',
#  'Untitled',
#  'AM',
#  'A Night At The Opera',
#  'Kind Of Blue',
#  'El Camino',
#  'Business As Usual',
#  'At Folsom Prison',
#  'Bon Iver, Bon Iver',
#  'MTV Unplugged In New York',
#  'Boston',
#  'Lonerism',
#  'Greatest Hits',
#  'Back To Black',
#  'Lover',
#  'Lift Your Skinny Fists Like Antennas To Heaven',
#  'The Wall',
#  'Siamese Dream',
#  'Back In Black',
#  'Led Zeppelin',
#  'The Queen Is Dead',
#  'Toys In The Attic',
#  'The Doors',
#  'Dummy',
#  'Scum Fuck Flower Boy',
#  '★ (Blackstar)',
#  'Sigh No More',
#  'Tattoo You',
#  'Abbey Road',
#  'The College Dropout',
#  'Weezer',
#  'A Moon Shaped Pool',
#  'In Rainbows',
#  'Bookends',
#  'Dookie',
#  'Band On The Run',
#  'Bella Donna',
#  'Igor',
#  'Good Kid, m.A.A.d City',
#  'Are You Experienced?',
#  'Running On Empty',
#  'Plastic Beach',
#  'OK Computer',
#  'The River',
#  'To Pimp A Butterfly',
#  'Breakfast In America',
#  'Abbey Road',
#  "Tomorrow's Harvest",
#  'Syro',
#  'Guardians Of The Galaxy',
#  'Nashville Skyline',
#  'Nevermind',
#  '21',
#  'Funeral',
#  'The Dark Side Of The Moon',
#  'Guardians Of The Galaxy Awesome Mix Vol. 1',
#  '2014 Forest Hills Drive',
#  'Ride The Lightning',
#  'Still Crazy After All These Years',
#  'The Wall',
#  '1984',
#  'Pulp Fiction (Music From The Motion Picture)',
#  'Santana',
#  "Outlandos D'Amour",
#  'Kids See Ghosts',
#  'Fly Like An Eagle',
#  'Born In The U.S.A.',
#  'Saturday Night Fever (The Original Movie Sound Track)',
#  'Little Creatures',
#  'Appetite For Destruction',
#  'Blunderbuss',
#  'In Utero',
#  "Sgt. Pepper's Lonely Hearts Club Band",
#  'Parallel Lines',
#  '...Like Clockwork',
#  'Born To Die',
#  'Heartbeat City',
#  'Aja',
#  'XX',
#  'Metallica',
#  'Speaking In Tongues',
#  'Rust Never Sleeps',
#  'An Innocent Man',
#  'Songs In The Key Of Life',
#  'Is This It',
#  'Unknown Pleasures',
#  'Homework',
#  'Ghost In The Machine',
#  'Gaucho',
#  'Around The World In A Day',
#  'Axis: Bold As Love',
#  'The Epic',
#  'L.A. Woman',
#  'Greatest Hits',
#  'When We All Fall Asleep, Where Do We Go?',
#  'Man On The Moon: The End Of Day',
#  'Rage Against The Machine',
#  "Sgt. Pepper's Lonely Hearts Club Band",
#  'The Wall',
#  'Thriller',
#  '1967-1970',
#  'Double Fantasy',
#  "Whatever People Say I Am, That's What I'm Not",
#  'Definitely Maybe',
#  'Love Over Gold',
#  'Buena Vista Social Club',
#  'Blood On The Tracks',
#  'Zenyatta Mondatta',
#  'The Suburbs',
#  "Chicago IX Chicago's Greatest Hits",
#  'Rumours',
#  'Currents',
#  'MTV Unplugged In New York',
#  'Brothers And Sisters',
#  'Animals',
#  'Point Of Know Return',
#  '25',
#  'The Rise And Fall Of Ziggy Stardust And The Spiders From Mars',
#  'Graceland',
#  'Kind Of Blue',
#  'Blood, Sweat And Tears',
#  'Endless Summer',
#  'Helplessness Blues',
#  'Led Zeppelin II',
#  'The Doors',
#  'Stranger In Town',
#  'Animals',
#  'Run The Jewels 3',
#  'Trouble Will Find Me',
#  'Ten',
#  '†',
#  'Ghosteen',
#  '"...Famous Last Words..."',
#  'Ten',
#  'Harry Styles',
#  'Reflektor',
#  'Animals',
#  'Damn.',
#  'Greatest Hits II',
#  'Legend - The Best Of Bob Marley And The Wailers',
#  'MTV Unplugged In New York',
#  'Cheap Thrills',
#  'The Beatles',
#  'True Blue',
#  'Illmatic',
#  '52nd Street',
#  'The Number Of The Beast',
#  'Briefcase Full Of Blues',
#  'Animals',
#  'Abbey Road',
#  '1989',
#  'Wish You Were Here',
#  'The Money Store',
#  'Blue Lines',
#  'Greatest Hits',
#  '1962-1966',
#  'Disintegration',
#  'm b v',
#  "Let's Dance",
#  'Reputation',
#  'Let It Bleed',
#  'Coming Home',
#  'Stardust',
#  '÷ (Divide)',
#  'Are You Experienced',
#  'Damn The Torpedoes',
#  '...But Seriously',
#  'Back In Black',
#  '"Rocks"',
#  'Currents',
#  'Night Moves',
#  'Wildflowers & All The Rest',
#  'Diamond Life',
#  'Hi Infidelity',
#  'Late Registration',
#  'Push The Sky Away',
#  'The Grand Illusion',
#  'Gorillaz',
#  'Doolittle',
#  'Some Girls',
#  'Private Eyes',
#  'Blue Monday',
#  'Their Greatest Hits 1971-1975',
#  'So',
#  'Everything All The Time',
#  "Simon And Garfunkel's Greatest Hits",
#  'Stop Making Sense',
#  'Desire',
#  'Van Halen II',
#  'Faith']

# %% [markdown]
# #### Artist Names

# %%
artists = []
for div in soup_1.find_all("div", {"class": "card card_large float_fix shortcut_navigable"}):
    for elem in div.find_all("h5"):
        artists.append(elem.get_text().replace("\n",""))
artists
# Out:
# ['Daft Punk',
#  'Kendrick Lamar',
#  'Michael Jackson',
#  'Pink Floyd',
#  'Fleetwood Mac',
#  'Pink Floyd',
#  'Jack White (2)',
#  'Prince And The Revolution',
#  'Nirvana',
#  'Neil Young',
#  'David Bowie',
#  'Eagles',
#  'Bruce Springsteen',
#  'Arctic Monkeys',
#  'Michael Jackson',
#  'Dire Straits',
#  'Crosby, Stills, Nash & Young',
#  'The Cars',
#  'Kanye West',
#  'The War On Drugs',
#  'Supertramp',
#  'Sufjan Stevens',
#  'Simon and Garfunkel*',
#  'Pink Floyd',
#  'Dr. Dre',
#  'Fleet Foxes',
#  'Oasis (2)',
#  'Billy Joel',
#  'Michael Jackson',
#  'Pink Floyd',
#  'Pink Floyd',
#  'Bon Iver',
#  'The Beatles',
#  'Tool (2)',
#  'Led Zeppelin',
#  'Carole King',
#  'Daft Punk',
#  'Johnny Cash',
#  'Various',
#  'Massive Attack',
#  'Radiohead',
#  'Amy Winehouse',
#  'Peter Frampton',
#  'Wu-Tang Clan',
#  'Doom* And Madlib - Madvillain',
#  'Pink Floyd',
#  'Foreigner',
#  'The Beatles',
#  'Neutral Milk Hotel',
#  'Billy Joel',
#  'Led Zeppelin',
#  'David Bowie',
#  'Simon & Garfunkel',
#  'Huey Lewis And The News*',
#  'John Williams (4), The London Symphony Orchestra',
#  'Alice In Chains',
#  'Michael Jackson',
#  'King Crimson',
#  'Fleetwood Mac',
#  'Janis Joplin',
#  'Journey',
#  'Led Zeppelin',
#  'Arctic Monkeys',
#  'Queen',
#  'Miles Davis',
#  'The Black Keys',
#  'Men At Work',
#  'Johnny Cash',
#  'Bon Iver',
#  'Nirvana',
#  'Boston',
#  'Tame Impala',
#  'Queen',
#  'Amy Winehouse',
#  'Taylor Swift',
#  'Godspeed You Black Emperor!',
#  'Pink Floyd',
#  'Smashing Pumpkins*',
#  'AC/DC',
#  'Led Zeppelin',
#  'The Smiths',
#  'Aerosmith',
#  'The Doors',
#  'Portishead',
#  'Tyler, The Creator',
#  'David Bowie',
#  'Mumford & Sons',
#  'Rolling Stones*',
#  'The Beatles',
#  'Kanye West',
#  'Weezer',
#  'Radiohead',
#  'Radiohead',
#  'Simon & Garfunkel',
#  'Green Day',
#  'Paul McCartney & Wings*',
#  'Stevie Nicks',
#  'Tyler, The Creator',
#  'Kendrick Lamar',
#  'The Jimi Hendrix Experience',
#  'Jackson Browne',
#  'Gorillaz',
#  'Radiohead',
#  'Bruce Springsteen',
#  'Kendrick Lamar',
#  'Supertramp',
#  'The Beatles',
#  'Boards Of Canada',
#  'Aphex Twin',
#  'Various',
#  'Bob Dylan',
#  'Nirvana',
#  'Adele (3)',
#  'Arcade Fire',
#  'Pink Floyd',
#  'Various',
#  'J. Cole',
#  'Metallica',
#  'Paul Simon',
#  'Pink Floyd',
#  'Van Halen',
#  'Various',
#  'Santana',
#  'The Police',
#  'Kids See Ghosts',
#  'Steve Miller Band',
#  'Bruce Springsteen',
#  'Various',
#  'Talking Heads',
#  "Guns N' Roses",
#  'Jack White (2)',
#  'Nirvana',
#  'The Beatles',
#  'Blondie',
#  'Queens Of The Stone Age',
#  'Lana Del Rey',
#  'The Cars',
#  'Steely Dan',
#  'The XX',
#  'Metallica',
#  'Talking Heads',
#  'Neil Young & Crazy Horse',
#  'Billy Joel',
#  'Stevie Wonder',
#  'The Strokes',
#  'Joy Division',
#  'Daft Punk',
#  'The Police',
#  'Steely Dan',
#  'Prince And The Revolution',
#  'The Jimi Hendrix Experience',
#  'Kamasi Washington',
#  'Doors*',
#  'Elton John',
#  'Billie Eilish',
#  'Kid Cudi',
#  'Rage Against The Machine',
#  'The Beatles',
#  'Pink Floyd',
#  'Michael Jackson',
#  'The Beatles',
#  'John Lennon & Yoko Ono',
#  'Arctic Monkeys',
#  'Oasis (2)',
#  'Dire Straits',
#  'Buena Vista Social Club',
#  'Bob Dylan',
#  'The Police',
#  'Arcade Fire',
#  'Chicago (2)',
#  'Fleetwood Mac',
#  'Tame Impala',
#  'Nirvana',
#  'The Allman Brothers Band',
#  'Pink Floyd',
#  'Kansas (2)',
#  'Adele (3)',
#  'David Bowie',
#  'Paul Simon',
#  'Miles Davis',
#  'Blood, Sweat And Tears',
#  'The Beach Boys',
#  'Fleet Foxes',
#  'Led Zeppelin',
#  'The Doors',
#  'Bob Seger & The Silver Bullet Band*',
#  'Pink Floyd',
#  'Run The Jewels',
#  'The National',
#  'Pearl Jam',
#  'Justice (3)',
#  'Nick Cave And The Bad Seeds*',
#  'Supertramp',
#  'Pearl Jam',
#  'Harry Styles',
#  'Arcade Fire',
#  'Pink Floyd',
#  'Kendrick Lamar',
#  'Queen',
#  'Bob Marley & The Wailers',
#  'Nirvana',
#  'Big Brother & The Holding Company',
#  'The Beatles',
#  'Madonna',
#  'Nas',
#  'Billy Joel',
#  'Iron Maiden',
#  'The Blues Brothers',
#  'Pink Floyd',
#  'The Beatles',
#  'Taylor Swift',
#  'Pink Floyd',
#  'Death Grips',
#  'Massive Attack',
#  'Tom Petty & The Heartbreakers*',
#  'The Beatles',
#  'The Cure',
#  'My Bloody Valentine',
#  'David Bowie',
#  'Taylor Swift',
#  'The Rolling Stones',
#  'Leon Bridges',
#  'Willie Nelson',
#  'Ed Sheeran',
#  'The Jimi Hendrix Experience',
#  'Tom Petty And The Heartbreakers',
#  'Phil Collins',
#  'AC/DC',
#  'Aerosmith',
#  'Tame Impala',
#  'Bob Seger & The Silver Bullet Band*',
#  'Tom Petty',
#  'Sade',
#  'REO Speedwagon',
#  'Kanye West',
#  'Nick Cave & The Bad Seeds',
#  'Styx',
#  'Gorillaz',
#  'Pixies',
#  'The Rolling Stones',
#  'Daryl Hall, John Oates*',
#  'New Order',
#  'Eagles',
#  'Peter Gabriel',
#  'Band Of Horses',
#  'Simon & Garfunkel',
#  'Talking Heads',
#  'Bob Dylan',
#  'Van Halen',
#  'George Michael']

# %%
pages_parsed = []
song_names = []
artists = []

for i in range(len(pages)):
    # parse all pages
    pages_parsed.append(BeautifulSoup(pages[i].content, "html.parser"))
    # select only the info about the movies
    #discogs_html = pages_parsed[i]
    for div in soup_1.find_all("div", {"class": "card card_large float_fix shortcut_navigable"}):
        for elem in div.find_all("h4"):
            song_names.append(elem.get_text().replace("\n",""))
    for div in soup_1.find_all("div", {"class": "card card_large float_fix shortcut_navigable"}):
        for elem in div.find_all("h5"):
            artists.append(elem.get_text().replace("\n",""))
        
        


# Checking our output:
print(len(song_names)) # output: 
print(len(artists))  # output:
# Out:
# 2000
# 2000

# %%
not_hot_songs = pd.DataFrame({"song_title":song_names,
                           "artist":artists})
not_hot_songs
# Out:
#                                song_title             artist
# 0                  Random Access Memories          Daft Punk
# 1                  Good Kid, M.A.A.d City     Kendrick Lamar
# 2                                Thriller    Michael Jackson
# 3               The Dark Side Of The Moon         Pink Floyd
# 4                                 Rumours      Fleetwood Mac
# ...                                   ...                ...
# 1995  Simon And Garfunkel's Greatest Hits  Simon & Garfunkel
# 1996                    Stop Making Sense      Talking Heads
# 1997                               Desire          Bob Dylan
# 1998                         Van Halen II          Van Halen
# 1999                                Faith     George Michael
#
# [2000 rows x 2 columns]

# %%
# If i wanted just a random fraction of theese. Not_hot_songs.sample(frac=0.2, replace=False, random_state=1)

# %%
#Savr them into a csv at the nd top_100_df.to_csv("hot100.csv",index=False)

# %%
# !ls
# Out:
# Lab_2                   Web_scraping_Lab1.ipynb
# README.md               hot100.csv
